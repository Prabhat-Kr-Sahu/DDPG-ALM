# %% [markdown]
# <a href="https://colab.research.google.com/github/Prabhat-Kr-Sahu/DDPG-ALM/blob/main/PRABHAT%2B_cmdp%2B_ddpg%2Balm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Portfolio Allocation
#
# Tutorials to use OpenAI DRL to perform portfolio allocation in one Jupyter Notebook | Presented at NeurIPS 2020: Deep RL Workshop
#
# * This blog is based on our paper: FinRL: A Deep Reinforcement Learning Library for Automated Stock Trading in Quantitative Finance, presented at NeurIPS 2020: Deep RL Workshop.
# * Check out medium blog for detailed explanations: https://towardsdatascience.com/finrl-for-quantitative-finance-tutorial-for-portfolio-allocation-9b417660c7cd
# * Please report any issues to our Github: https://github.com/AI4Finance-Foundation/FinRL/issues
#
# ESG-VARIABLES-PENALIZING
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# # **Problem Definition: Risk-Constrained Portfolio Optimization Using Deep Reinforcement Learning**
#
# This problem aims to design an **automated trading solution** for portfolio allocation while ensuring risk constraints are satisfied.
# We model the stock trading process as a **Constrained Markov Decision Process (CMDP)** and formulate our objective as a **constrained maximization problem**:
# - **Maximize** portfolio returns.
# - **Minimize** risk exposure within predefined limits.
#
# The algorithm is trained using **Deep Reinforcement Learning (DRL)** techniques, integrating **Deep Deterministic Policy Gradient (DDPG) with an Augmented Lagrangian Multiplier (ALM)** to handle risk constraints dynamically.
#
# ---
#
# ## **Reinforcement Learning Environment Components**
#
# ### **1️⃣ Action Space**
# - The **agent selects portfolio weights** for each asset at each time step.
# - Action vector:
#   \[
#   \mathbf{a} = [a_1, a_2, \dots, a_N], \quad \text{where } a_i \in (-1,1) \text{ and } \sum_{i=1}^{N} a_i = 1
#   \]
# - **Intuition:**
#   - \( a_i > 0 \) → **Long** position in stock \( i \).
#   - \( a_i < 0 \) → **Short** position in stock \( i \).
#   - \( a_i = 0 \) → No investment in stock \( i \).
# - Example: *"Allocate 10% of capital to AAPL"* → **Action = [0.1, ..., 0]**.
#
# ---
#
# ### **2️⃣ State Space**
# The agent **observes market conditions** before making trading decisions. The state vector contains:
# - **Price-based features**: Open, High, Low, Close, Volume (OHLCV).
# - **Technical indicators**: Moving Averages, RSI, MACD, Bollinger Bands.
# - **Risk metrics**: Portfolio variance, Value-at-Risk (VaR).
# - **Portfolio state**: Previous allocations, returns.
#
# \[
# \mathbf{s} = [\text{OHLCV}, \text{indicators}, \text{portfolio state}]
# \]
#
# *Example:*
# At time \( t \), the state could be:
# \[
# s_t = [\text{AAPL close}, \text{GOOGL RSI}, \text{Portfolio return}, \dots]
# \]
#
# ---
#
# ### **3️⃣ Reward Function**
# The agent receives a reward based on portfolio performance:
# \[
# r(s, a, s') = v' - v - \lambda \cdot \text{Risk}
# \]
# Where:
# - \( v' \) and \( v \) → Portfolio values before and after action.
# - \( \lambda \) → Lagrangian multiplier for risk constraint.
# - **Risk term**: VaR, variance, or drawdown penalty.
#
# This encourages the agent to **maximize return while controlling risk**.
#
# ---
#
# ### **4️⃣ Cost Function (Risk Constraint)**
# To enforce safety, we introduce a **risk-based cost function**:
# \[
# c(s, a) = \max( \text{VaR} - \text{Risk Threshold}, 0)
# \]
# - If **risk exceeds** the threshold, a penalty is applied.
# - Otherwise, the cost is **zero**.
# - The **Augmented Lagrangian Multiplier (ALM)** updates dynamically to enforce this constraint.
#
# ---
#
# ### **5️⃣ Environment**
# The trading environment consists of **S&P 500 stocks** (or another index).
# - **Data Source**: Yahoo Finance API, Alpha Vantage, or Quandl.
# - **Time Frame**: Daily, hourly, or minute-level data.
# - **Stock Pool**: Top 50 stocks based on market cap.
#
# Example:
# - **Dow 30 Constituents** (AAPL, MSFT, TSLA, etc.).
# - Data includes **OHLCV + technical indicators**.
#
# ---
#
# ### **Key Contributions of this Model**
# ✅ **Risk-aware DRL framework** for portfolio allocation.
# ✅ **Handles risk dynamically** using CMDP and ALM.
# ✅ **Optimized for long-short portfolio strategies**.
# ✅ **Scalable to multiple assets and real-world trading.**

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %%
pip install setuptools==66
# Out:
# Requirement already satisfied: setuptools==66 in /usr/local/lib/python3.11/dist-packages (66.0.0)

# %%
# !pip install stockstats
# !pip install hyperopt
# !pip install pyfolio
import stockstats
from hyperopt import fmin, tpe, hp, Trials, space_eval
# import pyfolio
from collections import deque
# Out:
# Collecting stockstats
#   Using cached stockstats-0.6.4-py2.py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.11/dist-packages (from stockstats) (2.0.2)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.11/dist-packages (from stockstats) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->stockstats) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->stockstats) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->stockstats) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->stockstats) (1.17.0)
# Using cached stockstats-0.6.4-py2.py3-none-any.whl (31 kB)
# Installing collected packages: stockstats
# Successfully installed stockstats-0.6.4
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.11/dist-packages (0.2.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from hyperopt) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from hyperopt) (1.14.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from hyperopt) (1.17.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.11/dist-packages (from hyperopt) (3.4.2)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from hyperopt) (1.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from hyperopt) (4.67.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from hyperopt) (3.1.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.11/dist-packages (from hyperopt) (0.10.9.7)

# %%
"""Contains methods and classes to collect data from
Yahoo Finance API
"""

from __future__ import annotations

import pandas as pd
import yfinance as yf


class YahooDownloader:
    """Provides methods for retrieving daily stock data from
    Yahoo Finance API

    Attributes
    ----------
        start_date : str
            start date of the data (modified from neofinrl_config.py)
        end_date : str
            end date of the data (modified from neofinrl_config.py)
        ticker_list : list
            a list of stock tickers (modified from neofinrl_config.py)

    Methods
    -------
    fetch_data()
        Fetches data from yahoo API

    """

    def __init__(self, start_date: str, end_date: str, ticker_list: list):
        self.start_date = start_date
        self.end_date = end_date
        self.ticker_list = ticker_list

    def fetch_data(self, proxy=None, auto_adjust=False) -> pd.DataFrame:
        """Fetches data from Yahoo API
        Parameters
        ----------

        Returns
        -------
        `pd.DataFrame`
            7 columns: A date, open, high, low, close, volume and tick symbol
            for the specified stock ticker
        """
        # Download and save the data in a pandas DataFrame:
        data_df = pd.DataFrame()
        num_failures = 0
        for tic in self.ticker_list:
            temp_df = yf.download(
                tic,
                start=self.start_date,
                end=self.end_date,
                proxy=proxy,
                auto_adjust=auto_adjust,
            )
            if temp_df.columns.nlevels != 1:
                temp_df.columns = temp_df.columns.droplevel(1)
            temp_df["tic"] = tic
            if len(temp_df) > 0:
                # data_df = data_df.append(temp_df)
                data_df = pd.concat([data_df, temp_df], axis=0)
            else:
                num_failures = num_failures+ 1
        if num_failures == len(self.ticker_list):
            raise ValueError("no data is fetched.")
        # reset the index, we want to use numbers as index instead of dates
        data_df = data_df.reset_index()
        try:
            # convert the column names to standardized names
            data_df.rename(
                columns={
                    "Date": "date",
                    "Adj Close": "adjcp",
                    "Close": "close",
                    "High": "high",
                    "Low": "low",
                    "Volume": "volume",
                    "Open": "open",
                    "tic": "tic",
                },
                inplace=True,
            )

            # use adjusted close price instead of close price
            data_df["close"] = data_df["adjcp"]
            # drop the adjusted close price column
            data_df = data_df.drop(labels="adjcp", axis=1)
        except NotImplementedError:
            print("the features are not supported currently")
        # create day of the week column (monday = 0)
        data_df["day"] = data_df["date"].dt.dayofweek
        # convert date to standard string format, easy to filter
        data_df["date"] = data_df.date.apply(lambda x: x.strftime("%Y-%m-%d"))
        # drop missing data
        data_df = data_df.dropna()
        data_df = data_df.reset_index(drop=True)
        print("Shape of DataFrame: ", data_df.shape)
        # print("Display DataFrame: ", data_df.head())

        data_df = data_df.sort_values(by=["date", "tic"]).reset_index(drop=True)

        return data_df

    def select_equal_rows_stock(self, df):
        df_check = df.tic.value_counts()
        df_check = pd.DataFrame(df_check).reset_index()
        df_check.columns = ["tic", "counts"]
        mean_df = df_check.counts.mean()
        equal_list = list(df.tic.value_counts() >= mean_df)
        names = df.tic.value_counts().index
        select_stocks_list = list(names[equal_list])
        df = df[df.tic.isin(select_stocks_list)]
        return df

# %%
import datetime
import numpy as np
import pandas as pd
from multiprocessing.sharedctypes import Value

import numpy as np
import pandas as pd
from stockstats import StockDataFrame as Sdf

def load_dataset(*, file_name: str) -> pd.DataFrame:
    """
    load csv dataset from path
    :return: (df) pandas dataframe
    """
    # _data = pd.read_csv(f"{config.DATASET_DIR}/{file_name}")
    _data = pd.read_csv(file_name)
    return _data


def data_split(df, start, end, target_date_col="date"):
    """
    split the dataset into training or testing using date
    :param data: (df) pandas dataframe, start, end
    :return: (df) pandas dataframe
    """
    data = df[(df[target_date_col] >= start) & (df[target_date_col] < end)]
    data = data.sort_values([target_date_col, "tic"], ignore_index=True)
    data.index = data[target_date_col].factorize()[0]
    return data


def convert_to_datetime(time):
    time_fmt = "%Y-%m-%dT%H:%M:%S"
    if isinstance(time, str):
        return datetime.datetime.strptime(time, time_fmt)

# %%
# from __future__ import annotations

# import copy
# import datetime
# from copy import deepcopy

# !pip install empyrical
# import empyrical as ep

# import matplotlib.dates as mdates
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# !pip install pyfolio
# import pyfolio
# from pyfolio import timeseries
# import itertools

# # Replacing from pyfolio import timeseries with original codes ##

# def gross_lev(positions):
#     """
#     Calculates the gross leverage of a strategy.

#     Parameters
#     ----------
#     positions : pd.DataFrame
#         Daily net position values.
#          - See full explanation in tears.create_full_tear_sheet.

#     Returns
#     -------
#     pd.Series
#         Gross leverage.
#     """

#     exposure = positions.drop('cash', axis=1).abs().sum(axis=1)
#     return exposure / positions.sum(axis=1)

# def get_txn_vol(transactions):
#     """
#     Extract daily transaction data from set of transaction objects.

#     Parameters
#     ----------
#     transactions : pd.DataFrame
#         Time series containing one row per symbol (and potentially
#         duplicate datetime indices) and columns for amount and
#         price.

#     Returns
#     -------
#     pd.DataFrame
#         Daily transaction volume and number of shares.
#          - See full explanation in tears.create_full_tear_sheet.
#     """

#     txn_norm = transactions.copy()
#     txn_norm.index = txn_norm.index.normalize()
#     amounts = txn_norm.amount.abs()
#     prices = txn_norm.price
#     values = amounts * prices
#     daily_amounts = amounts.groupby(amounts.index).sum()
#     daily_values = values.groupby(values.index).sum()
#     daily_amounts.name = "txn_shares"
#     daily_values.name = "txn_volume"
#     return pd.concat([daily_values, daily_amounts], axis=1)

# def get_turnover(positions, transactions, denominator='AGB'):
#     """
#      - Value of purchases and sales divided
#     by either the actual gross book or the portfolio value
#     for the time step.

#     Parameters
#     ----------
#     positions : pd.DataFrame
#         Contains daily position values including cash.
#         - See full explanation in tears.create_full_tear_sheet
#     transactions : pd.DataFrame
#         Prices and amounts of executed trades. One row per trade.
#         - See full explanation in tears.create_full_tear_sheet
#     denominator : str, optional
#         Either 'AGB' or 'portfolio_value', default AGB.
#         - AGB (Actual gross book) is the gross market
#         value (GMV) of the specific algo being analyzed.
#         Swapping out an entire portfolio of stocks for
#         another will yield 200% turnover, not 100%, since
#         transactions are being made for both sides.
#         - We use average of the previous and the current end-of-period
#         AGB to avoid singularities when trading only into or
#         out of an entire book in one trading period.
#         - portfolio_value is the total value of the algo's
#         positions end-of-period, including cash.

#     Returns
#     -------
#     turnover_rate : pd.Series
#         timeseries of portfolio turnover rates.
#     """

#     txn_vol = get_txn_vol(transactions)
#     traded_value = txn_vol.txn_volume

#     if denominator == 'AGB':
#         # Actual gross book is the same thing as the algo's GMV
#         # We want our denom to be avg(AGB previous, AGB current)
#         AGB = positions.drop('cash', axis=1).abs().sum(axis=1)
#         denom = AGB.rolling(2).mean()

#         # Since the first value of pd.rolling returns NaN, we
#         # set our "day 0" AGB to 0.
#         denom.iloc[0] = AGB.iloc[0] / 2
#     elif denominator == 'portfolio_value':
#         denom = positions.sum(axis=1)
#     else:
#         raise ValueError(
#             "Unexpected value for denominator '{}'. The "
#             "denominator parameter must be either 'AGB'"
#             " or 'portfolio_value'.".format(denominator)
#         )

#     denom.index = denom.index.normalize()
#     turnover = traded_value.div(denom, axis='index')
#     turnover = turnover.fillna(0)
#     return turnover

# SIMPLE_STAT_FUNCS = [
#     ep.annual_return,
#     ep.cum_returns_final,
#     ep.annual_volatility,
#     ep.sharpe_ratio,
#     ep.calmar_ratio,
#     ep.stability_of_timeseries,
#     # ep.max_drawdown,
#     ep.omega_ratio,
#     # ep.sortino_ratio,
#     # stats.skew,
#     # stats.kurtosis,
#     # ep.tail_ratio,
#     # value_at_risk
# ]

# FACTOR_STAT_FUNCS = [
#     # ep.alpha,
#     # ep.beta,
# ]

# STAT_FUNC_NAMES = {
#     'annual_return': 'Annual return',
#     'cum_returns_final': 'Cumulative returns',
#     'annual_volatility': 'Annual volatility',
#     'sharpe_ratio': 'Sharpe ratio',
#     'calmar_ratio': 'Calmar ratio',
#     'stability_of_timeseries': 'Stability',
#     # 'max_drawdown': 'Max drawdown',
#     'omega_ratio': 'Omega ratio',
#     # 'sortino_ratio': 'Sortino ratio',
#     # 'skew': 'Skew',
#     # 'kurtosis': 'Kurtosis',
#     # 'tail_ratio': 'Tail ratio',
#     # 'common_sense_ratio': 'Common sense ratio',
#     # 'value_at_risk': 'Daily value at risk',
#     # 'alpha': 'Alpha',
#     # 'beta': 'Beta',
# }


# def perf_stats(returns, factor_returns=None, positions=None,
#                transactions=None, turnover_denom='AGB'):
#     """
#     Calculates various performance metrics of a strategy, for use in
#     plotting.show_perf_stats.

#     Parameters
#     ----------
#     returns : pd.Series
#         Daily returns of the strategy, noncumulative.
#          - See full explanation in tears.create_full_tear_sheet.
#     factor_returns : pd.Series, optional
#         Daily noncumulative returns of the benchmark factor to which betas are
#         computed. Usually a benchmark such as market returns.
#          - This is in the same style as returns.
#          - If None, do not compute alpha, beta, and information ratio.
#     positions : pd.DataFrame
#         Daily net position values.
#          - See full explanation in tears.create_full_tear_sheet.
#     transactions : pd.DataFrame
#         Prices and amounts of executed trades. One row per trade.
#         - See full explanation in tears.create_full_tear_sheet.
#     turnover_denom : str
#         Either AGB or portfolio_value, default AGB.
#         - See full explanation in txn.get_turnover.

#     Returns
#     -------
#     pd.Series
#         Performance metrics.
#     """

#     stats = pd.Series()
#     for stat_func in SIMPLE_STAT_FUNCS:
#         stats[STAT_FUNC_NAMES[stat_func.__name__]] = stat_func(returns)

#     if positions is not None:
#         stats['Gross leverage'] = gross_lev(positions).mean()
#         if transactions is not None:
#             stats['Daily turnover'] = get_turnover(positions,
#                                                    transactions,
#                                                    turnover_denom).mean()
#     if factor_returns is not None:
#         for stat_func in FACTOR_STAT_FUNCS:
#             res = stat_func(returns, factor_returns)
#             stats[STAT_FUNC_NAMES[stat_func.__name__]] = res

#     return stats
# #######################
# def date2str(dat: datetime.date) -> str:
#     return datetime.date.strftime(dat, "%Y-%m-%d")

# def str2date(dat: str) -> datetime.date:
#     return datetime.datetime.strptime(dat, "%Y-%m-%d").date()

# def get_daily_return(df, value_col_name="account_value"):
#     df = deepcopy(df)
#     df["daily_return"] = df[value_col_name].pct_change(1)
#     df["date"] = pd.to_datetime(df["date"])
#     df.set_index("date", inplace=True, drop=True)
#     df.index = df.index.tz_localize("UTC")
#     return pd.Series(df["daily_return"], index=df.index)


# def convert_daily_return_to_pyfolio_ts(df):
#     strategy_ret = df.copy()
#     strategy_ret["date"] = pd.to_datetime(strategy_ret["date"])
#     strategy_ret.set_index("date", drop=False, inplace=True)
#     strategy_ret.index = strategy_ret.index.tz_localize("UTC")
#     del strategy_ret["date"]
#     return pd.Series(strategy_ret["daily_return"].values, index=strategy_ret.index)


# # def backtest_stats(account_value, value_col_name="account_value"):
# #     dr_test = get_daily_return(account_value, value_col_name=value_col_name)
# #     perf_stats_all = timeseries.perf_stats(
# #         returns=dr_test,
# #         positions=None,
# #         transactions=None,
# #         turnover_denom="AGB",
# #     )
# #     print(perf_stats_all)
# #     return perf_stats_all

# def backtest_stats(account_value, value_col_name="account_value"):
#     dr_test = get_daily_return(account_value, value_col_name=value_col_name)
#     perf_stats_all = perf_stats(
#         returns=dr_test,
#         positions=None,
#         transactions=None,
#         turnover_denom="AGB",
#     )
#     print(perf_stats_all)
#     return perf_stats_all


# # def backtest_plot(
# #     account_value,
# #     baseline_start=TRADE_START_DATE,
# #     baseline_end=TRADE_END_DATE,
# #     baseline_ticker="^DJI",
# #     value_col_name="account_value",
# # ):
# #     df = deepcopy(account_value)
# #     df["date"] = pd.to_datetime(df["date"])
# #     test_returns = get_daily_return(df, value_col_name=value_col_name)

# #     baseline_df = get_baseline(
# #         ticker=baseline_ticker, start=baseline_start, end=baseline_end
# #     )

# #     baseline_df["date"] = pd.to_datetime(baseline_df["date"], format="%Y-%m-%d")
# #     baseline_df = pd.merge(df[["date"]], baseline_df, how="left", on="date")
# #     baseline_df = baseline_df.fillna(method="ffill").fillna(method="bfill")
# #     baseline_returns = get_daily_return(baseline_df, value_col_name="close")

# #     with pyfolio.plotting.plotting_context(font_scale=1.1):
# #         pyfolio.create_full_tear_sheet(
# #             returns=test_returns, benchmark_rets=baseline_returns, set_context=False
# #         )


# def get_baseline(ticker, start, end):
#     return YahooDownloader(
#         start_date=start, end_date=end, ticker_list=[ticker]
#     ).fetch_data()


# def trx_plot(df_trade, df_actions, ticker_list):
#     df_trx = pd.DataFrame(np.array(df_actions["transactions"].to_list()))
#     df_trx.columns = ticker_list
#     df_trx.index = df_actions["date"]
#     df_trx.index.name = ""

#     for i in range(df_trx.shape[1]):
#         df_trx_temp = df_trx.iloc[:, i]
#         df_trx_temp_sign = np.sign(df_trx_temp)
#         buying_signal = df_trx_temp_sign.apply(lambda x: x > 0)
#         selling_signal = df_trx_temp_sign.apply(lambda x: x < 0)

#         tic_plot = df_trade[
#             (df_trade["tic"] == df_trx_temp.name)
#             & (df_trade["date"].isin(df_trx.index))
#         ]["close"]
#         tic_plot.index = df_trx_temp.index

#         plt.figure(figsize=(10, 8))
#         plt.plot(tic_plot, color="g", lw=2.0)
#         plt.plot(
#             tic_plot,
#             "^",
#             markersize=10,
#             color="m",
#             label="buying signal",
#             markevery=buying_signal,
#         )
#         plt.plot(
#             tic_plot,
#             "v",
#             markersize=10,
#             color="k",
#             label="selling signal",
#             markevery=selling_signal,
#         )
#         plt.title(
#             f"{df_trx_temp.name} Num Transactions: {len(buying_signal[buying_signal == True]) + len(selling_signal[selling_signal == True])}"
#         )
#         plt.legend()
#         plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=25))
#         plt.xticks(rotation=45, ha="right")
#         plt.show()


# # 2022-01-15 -> 01/15/2022
# def transfer_date(str_dat):
#     return datetime.datetime.strptime(str_dat, "%Y-%m-%d").date().strftime("%m/%d/%Y")


# def plot_result_from_csv(
#     csv_file: str,
#     column_as_x: str,
#     savefig_filename: str = "fig/result.png",
#     xlabel: str = "Date",
#     ylabel: str = "Result",
#     num_days_xticks: int = 20,
#     xrotation: int = 0,
# ):
#     result = pd.read_csv(csv_file)
#     plot_result(
#         result,
#         column_as_x,
#         savefig_filename,
#         xlabel,
#         ylabel,
#         num_days_xticks,
#         xrotation,
#     )


# # select_start_date: included
# # select_end_date: included
# # is if_need_calc_return is True, it is account_value, and then transfer it to return
# # it is better that column_as_x is the first column, and the other columns are strategies
# # xrotation: the rotation of xlabel, may be used in dates. Default=0 (adaptive adjustment)
# def plot_result(
#     result: pd.DataFrame(),
#     column_as_x: str,
#     savefig_filename: str = "fig/result.png",
#     xlabel: str = "Date",
#     ylabel: str = "Result",
#     num_days_xticks: int = 20,
#     xrotation: int = 0,
# ):
#     columns = result.columns
#     columns_strtegy = []
#     for i in range(len(columns)):
#         col = columns[i]
#         if "Unnamed" not in col and col != column_as_x:
#             columns_strtegy.append(col)

#     result.reindex()

#     x = result[column_as_x].values.tolist()
#     plt.rcParams["figure.figsize"] = (15, 6)
#     # plt.figure()

#     fig, ax = plt.subplots()
#     colors = [
#         "black",
#         "red",
#         "green",
#         "blue",
#         "cyan",
#         "magenta",
#         "yellow",
#         "aliceblue",
#         "coral",
#         "darksalmon",
#         "firebrick",
#         "honeydew",
#     ]
#     for i in range(len(columns_strtegy)):
#         col = columns_strtegy[i]
#         ax.plot(
#             x,
#             result[col],
#             color=colors[i],
#             linewidth=1,
#             linestyle="-",
#         )

#     plt.title("", fontsize=20)
#     plt.xlabel(xlabel, fontsize=20)
#     plt.ylabel(ylabel, fontsize=20)

#     plt.legend(labels=columns_strtegy, loc="best", fontsize=16)

#     # set grid
#     plt.grid()

#     plt.xticks(size=22)  # 设置刻度大小
#     plt.yticks(size=22)  # 设置刻度大小

#     # #设置每隔多少距离⼀个刻度
#     # plt.xticks(x[::60])

#     # # 设置每月定位符
#     # if if_set_x_monthlocator:
#     #     ax.xaxis.set_major_locator(mdates.MonthLocator())  # interval = 1

#     # 设置每隔多少距离⼀个刻度
#     plt.xticks(x[::num_days_xticks])

#     plt.setp(ax.get_xticklabels(), rotation=xrotation, horizontalalignment="center")

#     # 为防止x轴label重叠，自动调整label旋转角度
#     if xrotation == 0:
#         if_overlap = get_if_overlap(fig, ax)

#         if if_overlap == True:
#             plt.gcf().autofmt_xdate(ha="right")  # ⾃动旋转⽇期标记

#     plt.tight_layout()  # 自动调整子图间距

#     plt.savefig(savefig_filename)

#     plt.show()


# def get_if_overlap(fig, ax):
#     fig.canvas.draw()
#     # 获取日期标签的边界框
#     bboxes = [label.get_window_extent() for label in ax.get_xticklabels()]
#     # 计算日期标签之间的距离
#     distances = [bboxes[i + 1].x0 - bboxes[i].x1 for i in range(len(bboxes) - 1)]
#     # 如果有任何距离小于0，说明有重叠
#     if any(distance < 0 for distance in distances):
#         if_overlap = True
#     else:
#         if_overlap = False

#     return if_overlap


# def plot_return(
#     result: pd.DataFrame(),
#     column_as_x: str,
#     if_need_calc_return: bool,
#     savefig_filename: str = "fig/result.png",
#     xlabel: str = "Date",
#     ylabel: str = "Return",
#     if_transfer_date: bool = True,
#     select_start_date: str = None,
#     select_end_date: str = None,
#     num_days_xticks: int = 20,
#     xrotation: int = 0,
# ):
#     if select_start_date is None:
#         select_start_date: str = result[column_as_x].iloc[0]
#         select_end_date: str = result[column_as_x].iloc[-1]
#     # calc returns if if_need_calc_return is True, so that result stores returns
#     select_start_date_index = result[column_as_x].tolist().index(select_start_date)
#     columns = result.columns
#     columns_strtegy = []
#     column_as_x_index = None
#     for i in range(len(columns)):
#         col = columns[i]
#         if col == column_as_x:
#             column_as_x_index = i
#         elif "Unnamed" not in col:
#             columns_strtegy.append(col)
#             if if_need_calc_return:
#                 result[col] = result[col] / result[col][select_start_date_index] - 1

#     # select the result between select_start_date and select_end_date
#     # if date is 2020-01-15, transfer it to 01/15/2020
#     num_rows, num_cols = result.shape
#     tmp_result = copy.deepcopy(result)
#     result = pd.DataFrame()
#     if_first_row = True
#     columns = []
#     for i in range(num_rows):
#         if (
#             str2date(select_start_date)
#             <= str2date(tmp_result[column_as_x][i])
#             <= str2date(select_end_date)
#         ):
#             if "-" in tmp_result.iloc[i][column_as_x] and if_transfer_date:
#                 new_date = transfer_date(tmp_result.iloc[i][column_as_x])
#             else:
#                 new_date = tmp_result.iloc[i][column_as_x]
#             tmp_result.iloc[i, column_as_x_index] = new_date
#             # print("tmp_result.iloc[i]: ", tmp_result.iloc[i])
#             # result = result.append(tmp_result.iloc[i])
#             if if_first_row:
#                 columns = tmp_result.iloc[i].index.tolist()
#                 result = pd.DataFrame(columns=columns)
#                 # result = pd.concat([result, tmp_result.iloc[i]], axis=1)
#                 # result = pd.DataFrame(tmp_result.iloc[i])
#                 # result.columns = tmp_result.iloc[i].index.tolist()
#                 if_first_row = False
#             row = pd.DataFrame([tmp_result.iloc[i].tolist()], columns=columns)
#             result = pd.concat([result, row], axis=0)

#     # print final return of each strategy
#     final_return = {}
#     for col in columns_strtegy:
#         final_return[col] = result.iloc[-1][col]
#     print("final return: ", final_return)

#     result.reindex()

#     plot_result(
#         result=result,
#         column_as_x=column_as_x,
#         savefig_filename=savefig_filename,
#         xlabel=xlabel,
#         ylabel=ylabel,
#         num_days_xticks=num_days_xticks,
#         xrotation=xrotation,
#     )


# def plot_return_from_csv(
#     csv_file: str,
#     column_as_x: str,
#     if_need_calc_return: bool,
#     savefig_filename: str = "fig/result.png",
#     xlabel: str = "Date",
#     ylabel: str = "Return",
#     if_transfer_date: bool = True,
#     select_start_date: str = None,
#     select_end_date: str = None,
#     num_days_xticks: int = 20,
#     xrotation: int = 0,
# ):
#     result = pd.read_csv(csv_file)
#     plot_return(
#         result,
#         column_as_x,
#         if_need_calc_return,
#         savefig_filename,
#         xlabel,
#         ylabel,
#         if_transfer_date,
#         select_start_date,
#         select_end_date,
#         num_days_xticks,
#         xrotation,
#     )

# %%
import copy
import datetime
import os
from datetime import date
from datetime import timedelta
from typing import List
from typing import Tuple

import numpy as np
import pandas as pd

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install 'shimmy>=2.0'
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %%
# !pip install hyperopt
from hyperopt import fmin, tpe, hp, Trials, space_eval
# Out:
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.11/dist-packages (0.2.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from hyperopt) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from hyperopt) (1.14.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from hyperopt) (1.17.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.11/dist-packages (from hyperopt) (3.4.2)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from hyperopt) (1.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from hyperopt) (4.67.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from hyperopt) (3.1.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.11/dist-packages (from hyperopt) (0.10.9.7)

# %%
# #Importing the libraries
# !pip install pandas_market_calendars
# import pandas as pd
# import numpy as np
# import matplotlib
# import matplotlib.pyplot as plt
# matplotlib.use('Agg')
# import datetime
# %matplotlib inline
# from finrl import config
# from finrl import config_tickers
# from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
# from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
# from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
# from finrl.meta.env_stock_trading.env_stocktrading_np import StockTradingEnv as StockTradingEnv_numpy
# from finrl.agents.stablebaselines3.models import DRLAgent
# # from finrl.agents.rllib.models import DRLAgent as DRLAgent_rllib
# from finrl.meta.data_processor import DataProcessor
# import joblib
# from stable_baselines3.common.logger import configure
# from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline,convert_daily_return_to_pyfolio_ts
# from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor
# import ray
# from pprint import pprint

# import sys
# sys.path.append("../FinRL-Library")

# import itertools

# %%
# import pandas as pd
# import numpy as np
# import matplotlib
# import matplotlib.pyplot as plt
# matplotlib.use('Agg')
# %matplotlib inline
# import datetime

# from finrl import config
# from finrl import config_tickers
# from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
# from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
# from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
# from finrl.agents.stablebaselines3.models import DRLAgent
# from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline,convert_daily_return_to_pyfolio_ts
# from finrl.meta.data_processor import DataProcessor
# from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor
# import sys
# sys.path.append("../FinRL-Library")

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
# import os
# if not os.path.exists("./" + config.DATA_SAVE_DIR):
#     os.makedirs("./" + config.DATA_SAVE_DIR)
# if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
#     os.makedirs("./" + config.TRAINED_MODEL_DIR)
# if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
#     os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
# if not os.path.exists("./" + config.RESULTS_DIR):
#     os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %%
Nifty_ticker = ['RELIANCE.NS', 'ASIANPAINT.NS', 'BAJFINANCE.NS', 'HDFCBANK.NS', 'SBIN.NS']
sensex_ticker = ["ASIANPAINT.NS", "AXISBANK.NS", "BAJFINANCE.NS", "BAJAJFINSV.NS", "BHARTIARTL.NS", "HCLTECH.NS", "HDFCBANK.NS",
                 "HINDUNILVR.NS", "ICICIBANK.NS", "INDUSINDBK.NS", "INFY.NS", "ITC.NS", "JSWSTEEL.NS", "KOTAKBANK.NS", "LT.NS",
                 "M&M.NS", "MARUTI.NS", "NESTLEIND.NS", "NTPC.NS", "POWERGRID.NS", "RELIANCE.NS", "SBIN.NS", "SUNPHARMA.NS",
                 "TATAMOTORS.NS", "TATASTEEL.NS", "TCS.NS", "TECHM.NS", "TITAN.NS", "ULTRACEMCO.NS", "WIPRO.NS"]


# BIST Turkey
bist100_top30_tickers = ['AEFES.IS', 'AKBNK.IS', 'ARCLK.IS', 'ASELS.IS', 'BIMAS.IS', 'CCOLA.IS',
       'DOHOL.IS', 'EKGYO.IS', 'ENKAI.IS', 'EREGL.IS', 'FROTO.IS', 'GARAN.IS',
       'GOLTS.IS', 'HALKB.IS', 'ISCTR.IS', 'KCHOL.IS', 'KOZAL.IS', 'KRDMD.IS',
       'PETKM.IS', 'SAHOL.IS', 'SISE.IS', 'TAVHL.IS', 'TCELL.IS', 'THYAO.IS',
       'TKFEN.IS', 'TOASO.IS', 'TTKOM.IS', 'TUPRS.IS', 'ULKER.IS', 'VAKBN.IS',
       'VESTL.IS', 'YKBNK.IS']

# Spain IBEX top 30
ibex35_tickers = ['ACS.MC', 'ACX.MC', 'AMS.MC', 'ANA.MC', 'BBVA.MC', 'BKT.MC', 'CABK.MC',
       'COL.MC', 'ELE.MC', 'ENG.MC', 'FDR.MC', 'FER.MC', 'GRF.MC', 'IBE.MC',
       'IDR.MC', 'ITX.MC', 'MAP.MC', 'MEL.MC', 'MTS.MC', 'NTGY.MC', 'RED.MC',
       'REP.MC', 'ROVI.MC', 'SAB.MC', 'SAN.MC', 'SCYR.MC', 'SLR.MC', 'TEF.MC']

# Tickers for the top 30 stocks on B3 (Brasil Bolsa Balcão)

brazil_tickers = ['ABEV3.SA', 'BBAS3.SA', 'BPAN4.SA', 'BRFS3.SA', 'BRKM5.SA', 'CSNA3.SA',
       'CYRE3.SA', 'ECOR3.SA', 'EGIE3.SA', 'ELET3.SA', 'ELET6.SA', 'EMBR3.SA',
       'EQTL3.SA', 'GGBR4.SA', 'ITUB4.SA', 'JBSS3.SA', 'LREN3.SA',
       'MRFG3.SA', 'PETR3.SA', 'PETR4.SA', 'RADL3.SA', 'RENT3.SA', 'SBSP3.SA',
       'SUZB3.SA', 'UGPA3.SA', 'USIM5.SA', 'VALE3.SA', 'WEGE3.SA', 'YDUQ3.SA']


# Final Tickers Hang Seng (Hong Kong)
hang_seng_symbols = ['0002.HK', '0003.HK', '0012.HK', '0017.HK', '0027.HK', '0101.HK',
       '0241.HK', '0267.HK', '0669.HK', '0762.HK', '0836.HK', '0883.HK',
       '0906.HK', '0939.HK', '0992.HK', '1038.HK', '1044.HK', '1093.HK',
       '1109.HK', '1398.HK', '2020.HK', '2319.HK', '2331.HK', '2382.HK',
       '2628.HK', '2688.HK', '3323.HK', '3328.HK', '3983.HK', '3988.HK']

# Tiwan TWSE Market
twse_top30 = ['1216.TW', '1301.TW', '1303.TW', '1519.TW', '1537.TW', '2308.TW',
       '2317.TW', '2330.TW', '2363.TW', '2368.TW', '2382.TW', '2412.TW',
       '2454.TW', '2474.TW', '2504.TW', '2603.TW', '2838.TW', '2880.TW',
       '2881.TW', '2882.TW', '2884.TW', '2886.TW', '2891.TW', '2892.TW',
       '3008.TW', '3045.TW', '3653.TW', '4904.TW', '5880.TW', '6505.TW']
# UK FTSE top 30 working Stock
FTSE_top30 = ['ABF.L', 'ADM.L', 'AHT.L', 'AV.L', 'BA.L', 'BEZ.L', 'CCL.L', 'CNA.L',
       'DPLM.L', 'ENT.L', 'FRAS.L', 'HSBA.L', 'HWDN.L', 'III.L',
       'IMI.L', 'INF.L', 'MKS.L', 'MRO.L', 'NXT.L', 'PSON.L', 'REL.L', 'RR.L',
       'SBRY.L', 'SKG.L', 'SMDS.L', 'SMIN.L', 'SMT.L', 'SPX.L', 'SSE.L']
# Japanies Nikkei Top 30
nikkei_top30_symbols = ['2914.T', '3382.T', '3407.T', '3861.T', '4063.T', '4502.T', '4689.T',
       '4755.T', '5802.T', '6301.T', '6471.T', '6501.T', '6594.T', '6701.T',
       '6758.T', '6920.T', '7011.T', '7203.T', '7267.T', '7735.T', '7974.T',
       '8031.T', '8035.T', '8058.T', '8306.T', '8316.T', '9020.T', '9022.T',
       '9983.T', '9984.T']
# German DAX top 30
dax_30 = ['ADS.DE', 'AIR.DE', 'ALV.DE', 'BAS.DE', 'BEI.DE', 'BMW.DE', 'BNR.DE',
       'BOSS.DE', 'CBK.DE', 'CON.DE', 'DB1.DE', 'DBK.DE', 'DTE.DE', 'DWNI.DE',
       'EOAN.DE', 'EVT.DE', 'FME.DE', 'FNTN.DE', 'FRE.DE', 'HEI.DE', 'HNR1.DE',
       'LIN.DE', 'MRK.DE', 'MTX.DE', 'MUV2.DE', 'SAP.DE', 'SIE.DE', 'SY1.DE',
       'TL0.DE', 'VOW3.DE']
# USA Dow 30
Dow_30 = ['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM', 'CSCO', 'CVX', 'DIS', 'GS',
       'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM', 'MRK',
       'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ', 'WBA', 'WMT']

indices= [sensex_ticker, Dow_30, dax_30, nikkei_top30_symbols, FTSE_top30, twse_top30, hang_seng_symbols, brazil_tickers, ibex35_tickers, bist100_top30_tickers ]


# Download and save the data in a pandas DataFrame:
df = YahooDownloader(start_date = '2011-01-01',
                     end_date = '2025-02-28',
                     ticker_list = sensex_ticker).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (104760, 8)

# %%
df.shape
# Out:
# (104760, 8)

# %%
from stockstats import StockDataFrame as Sdf

def add_tech(data, INDICATORS):
  df = data.copy()
  df = df.sort_values(by=["tic", "date"])
  stock = Sdf.retype(df.copy())
  unique_ticker = stock.tic.unique()

  for indicator in INDICATORS:
      indicator_df = pd.DataFrame()
      for i in range(len(unique_ticker)):
          try:
              temp_indicator = stock[stock.tic == unique_ticker[i]][indicator]
              temp_indicator = pd.DataFrame(temp_indicator)
              temp_indicator["tic"] = unique_ticker[i]
              temp_indicator["date"] = df[df.tic == unique_ticker[i]][
                  "date"
              ].to_list()
              # indicator_df = indicator_df.append(
              #     temp_indicator, ignore_index=True
              # )
              indicator_df = pd.concat(
                  [indicator_df, temp_indicator], axis=0, ignore_index=True
              )
          except Exception as e:
              print(e)
      df = df.merge(
          indicator_df[["tic", "date", indicator]], on=["tic", "date"], how="left"
      )

  df = df.sort_values(by=["date", "tic"])

  return df

# %%
INDICATORS = ['macd', 'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30', 'close_30_sma', 'close_60_sma']
df = add_tech(df, INDICATORS)
df = df.ffill().bfill()

# %%
# add covariance matrix as states
df=df.sort_values(['date','tic'],ignore_index=True)
df.index = df.date.factorize()[0]

cov_list = []
return_list = []

# look back is one year
lookback=252
for i in range(lookback,len(df.index.unique())):
  data_lookback = df.loc[i-lookback:i,:]
  price_lookback=data_lookback.pivot_table(index = 'date',columns = 'tic', values = 'close')
  return_lookback = price_lookback.pct_change().dropna()
  return_list.append(return_lookback)

  covs = return_lookback.cov().values
  cov_list.append(covs)


df_cov = pd.DataFrame({'date':df.date.unique()[lookback:],'cov_list':cov_list,'return_list':return_list})
df = df.merge(df_cov, on='date')
df = df.sort_values(['date','tic']).reset_index(drop=True)

# %%
df['cov_list'].head(3)
# Out:
# 0    [[0.00021241411217716384, 8.694810648803102e-0...
# 1    [[0.00021241411217716384, 8.694810648803102e-0...
# 2    [[0.00021241411217716384, 8.694810648803102e-0...
# Name: cov_list, dtype: object

# %%
df.head(50)
# Out:
#           date        close         high          low         open    volume  \
# 0   2012-01-10   238.461319   269.500000   264.500000   268.855011    338040
# 1   2012-01-10   166.384033   179.399994   173.220001   173.800003   9827090
# 2   2012-01-10    42.398289    43.130127    42.245911    42.589771    295237
# 3   2012-01-10    57.317436    61.403934    59.315037    60.223461     35673
# 4   2012-01-10   278.227142   300.479187   289.348633   289.348633   9865514
# 5   2012-01-10    77.642136   105.162498   104.199997   104.750000   6297316
# 6   2012-01-10   207.453506   231.149994   228.000000   230.000000   4491386
# 7   2012-01-10   318.154602   399.000000   391.700012   393.500000   1818282
# 8   2012-01-10   119.659370   141.636368   136.372726   136.490906  22240036
# 9   2012-01-10   241.015976   262.950012   247.300003   248.850006   2507816
# 10  2012-01-10   263.024170   359.424988   356.274994   358.750000  11179176
# 11  2012-01-10    96.684898   137.166672   134.800003   134.800003   5412396
# 12  2012-01-10    52.919853    63.434998    57.299999    57.700001  47065780
# 13  2012-01-10   231.175797   234.875000   227.600006   228.000000   1079256
# 14  2012-01-10   415.130585   506.755554   486.777771   486.777771   6069096
# 15  2012-01-10   305.317352   347.299988   328.325012   329.450012   4719090
# 16  2012-01-10   882.286072   993.000000   977.250000   981.000000    356547
# 17  2012-01-10   349.653503   412.515015   408.450012   409.899994    234660
# 18  2012-01-10    77.407051   133.458328   130.625000   132.458328   7592079
# 19  2012-01-10    35.136803    58.106262    56.840637    56.840637   3215986
# 20  2012-01-10   143.208298   168.922974   162.751221   162.751221  19720278
# 21  2012-01-10   146.945831   170.875000   164.899994   164.975006  28087310
# 22  2012-01-10   235.766068   260.000000   253.475006   253.550003   1689898
# 23  2012-01-10   195.843430   204.259109   198.866959   198.866959  11914873
# 24  2012-01-10    11.758810    35.575188    34.412846    34.412846  54776879
# 25  2012-01-10   459.460388   592.750000   579.250000   587.500000   3591790
# 26  2012-01-10   117.008087   153.750000   151.250000   151.250000    340888
# 27  2012-01-10   167.361649   181.750000   176.449997   177.899994   1857788
# 28  2012-01-10  1107.437866  1176.900024  1150.000000  1150.000000     98735
# 29  2012-01-10    64.279449    76.425018    75.356270    75.759392   6348942
# 30  2012-01-11   244.183716   272.989990   264.000000   268.855011   1111290
# 31  2012-01-11   173.617722   189.490005   178.619995   179.600006  15532065
# 32  2012-01-11    42.577923    43.410130    42.319595    42.884510    345336
# 33  2012-01-11    59.524239    64.610153    61.112461    61.112461    317955
# 34  2012-01-11   274.268707   299.217407   291.286346   299.217407   6875226
# 35  2012-01-11    76.791573   106.224998   103.199997   105.949997   2967676
# 36  2012-01-11   208.784821   232.000000   227.500000   230.250000   3859556
# 37  2012-01-11   315.781311   398.700012   391.350006   396.850006   1313159
# 38  2012-01-11   120.532303   143.636368   140.572723   141.472733  27287084
# 39  2012-01-11   251.778107   273.899994   263.000000   263.000000   1268889
# 40  2012-01-11   259.625641   361.862488   351.625000   358.500000  13795800
# 41  2012-01-11    95.813034   137.066666   135.000000   136.766663   8114019
# 42  2012-01-11    53.658993    64.790001    61.855000    63.099998  45764080
# 43  2012-01-11   230.556351   234.975006   229.500000   233.250000    932130
# 44  2012-01-11   420.000275   511.555542   498.311096   505.777771   4396176
# 45  2012-01-11   301.396729   346.250000   334.549988   345.750000   4350152
# 46  2012-01-11   883.672607   995.000000   972.200012   988.549988    433994
# 47  2012-01-11   346.286285   410.000000   405.200012   406.404999    406730
# 48  2012-01-11    78.239899   133.708328   131.250000   132.333328   7652688
# 49  2012-01-11    34.314888    57.768764    56.193764    57.768764   4377469
#
#               tic  day       macd      boll_ub      boll_lb     rsi_30  \
# 0   ASIANPAINT.NS    1  -4.954875   249.625782   230.018978  40.195484
# 1     AXISBANK.NS    1  -5.285489   175.857182   144.370964  44.932199
# 2   BAJAJFINSV.NS    1  -0.579625    43.435291    38.436663  45.362715
# 3   BAJFINANCE.NS    1  -0.950271    60.000609    53.893184  47.765410
# 4   BHARTIARTL.NS    1  -7.057580   300.710558   270.360445  42.690375
# 5      HCLTECH.NS    1   0.486612    79.006047    69.610510  53.259858
# 6     HDFCBANK.NS    1   0.739974   209.047962   184.393904  52.614533
# 7   HINDUNILVR.NS    1   1.783620   338.774563   308.162788  54.611781
# 8    ICICIBANK.NS    1   0.158811   120.135271   100.072731  50.542242
# 9   INDUSINDBK.NS    1  -1.906377   240.877903   206.581345  52.800377
# 10        INFY.NS    1   3.484094   265.963827   242.999782  57.513351
# 11         ITC.NS    1   0.107378    97.233774    92.403431  53.177272
# 12    JSWSTEEL.NS    1   0.375710    51.668809    38.458302  54.023183
# 13   KOTAKBANK.NS    1  -2.902935   242.799098   209.507632  50.428321
# 14          LT.NS    1 -11.263024   422.515925   346.325115  44.339417
# 15         M&M.NS    1  -7.134339   315.803238   280.874674  46.289502
# 16      MARUTI.NS    1  -5.021248   885.832384   810.087202  48.896354
# 17   NESTLEIND.NS    1  -2.268508   362.026219   341.581362  46.745876
# 18        NTPC.NS    1  -0.939406    81.047033    75.567528  45.711946
# 19   POWERGRID.NS    1   0.169198    35.271260    33.147894  53.520781
# 20    RELIANCE.NS    1  -3.315362   149.663711   133.881745  46.365728
# 21        SBIN.NS    1  -2.083874   151.842302   135.140533  46.557944
# 22   SUNPHARMA.NS    1  -0.086953   237.613128   222.282549  54.852265
# 23  TATAMOTORS.NS    1   5.741314   198.547698   156.644087  59.079568
# 24   TATASTEEL.NS    1  -0.238410    12.024737    10.529720  45.319367
# 25         TCS.NS    1   3.775152   472.755444   447.685199  54.170473
# 26       TECHM.NS    1   1.413208   117.027902   104.587113  54.101613
# 27       TITAN.NS    1  -1.963796   170.814914   146.579954  47.037287
# 28  ULTRACEMCO.NS    1   0.499666  1137.920043  1060.690248  52.543389
# 29       WIPRO.NS    1   0.710510    66.688176    62.381245  54.329982
# 30  ASIANPAINT.NS    2  -4.189428   248.417475   230.664911  43.999482
# 31    AXISBANK.NS    2  -3.804078   174.570992   145.182968  48.224095
# 32  BAJAJFINSV.NS    2  -0.450523    43.554319    38.665736  45.793824
# 33  BAJFINANCE.NS    2  -0.616004    60.043763    53.869677  52.531903
# 34  BHARTIARTL.NS    2  -7.391055   300.011956   269.109306  41.754365
# 35     HCLTECH.NS    2   0.561476    79.103748    69.580299  51.922422
# 36    HDFCBANK.NS    2   1.336403   210.804676   183.914318  53.330750
# 37  HINDUNILVR.NS    2   1.183930   338.076575   309.508431  53.417199
# 38   ICICIBANK.NS    2   0.714407   121.722615    99.655716  51.134868
# 39  INDUSINDBK.NS    2   0.318890   245.488742   203.771895  56.039890
# 40        INFY.NS    2   3.329837   266.502020   243.254714  55.339453
# 41         ITC.NS    2   0.159417    97.334947    92.464854  51.508551
# 42    JSWSTEEL.NS    2   0.838087    53.110385    37.821381  54.752773
# 43   KOTAKBANK.NS    2  -2.187617   240.664650   210.504784  50.178568
# 44          LT.NS    2  -8.275466   421.293530   347.082510  45.431076
# 45         M&M.NS    2  -6.270804   315.945667   280.922729  45.201807
# 46      MARUTI.NS    2  -2.339489   890.859565   808.660369  49.073548
# 47   NESTLEIND.NS    2  -2.469275   361.708987   340.988602  45.293515
# 48        NTPC.NS    2  -0.838762    80.756882    75.642115  46.975227
# 49   POWERGRID.NS    2   0.141442    35.170686    33.380317  50.128666
#
#         cci_30      dx_30  close_30_sma  close_60_sma  \
# 0   -53.404711  30.113608    245.088729    260.401532
# 1   -19.455755  18.677290    168.103824    183.434646
# 2    43.496551   7.443321     41.387001     45.780652
# 3   -37.039046  19.916950     57.761540     59.338969
# 4   -94.654376  18.773105    294.552157    310.406227
# 5    89.772806  11.707098     74.634638     75.968688
# 6   122.467494   6.279865    198.758086    205.131291
# 7   -26.916465  12.013835    320.520041    307.358469
# 8   112.041032   7.468154    111.680534    120.539500
# 9    55.051967   4.824699    229.539477    237.717298
# 10  151.841069  11.024323    252.138463    252.546492
# 11   94.112017   3.308226     94.747124     95.851903
# 12   96.777368   0.349227     46.753918     49.390041
# 13   -4.295054   3.679330    230.450642    234.294905
# 14   -0.327336  17.427367    410.730798    449.305570
# 15  -28.754419   9.327809    306.018036    328.495621
# 16   98.262600   2.938698    856.324815    897.292734
# 17  -61.454611  18.134643    353.490302    359.115706
# 18  -69.620637  13.545080     79.463895     81.335790
# 19  118.604123   2.345553     34.189315     34.397076
# 20  -47.610822   0.165271    144.930495    154.284651
# 21  -28.989646  11.959863    148.553019    153.408778
# 22   45.342157   8.450291    232.079027    229.143842
# 23  169.230096  16.799988    176.833592    175.493595
# 24  -11.185918  15.304003     11.738197     12.666513
# 25   26.226669   9.833295    459.141723    445.088258
# 26  177.972806  10.794889    110.090422    111.497046
# 27   42.517886  11.635868    162.318130    178.839135
# 28    2.955858  11.791016   1105.682296   1094.110750
# 29   19.727158  19.808691     64.093625     61.337863
# 30  -26.252883  25.103615    244.435848    259.735696
# 31   22.682202   8.827593    167.842556    182.939694
# 32   62.758510   5.997409     41.316281     45.630310
# 33   69.877061   5.860558     57.806011     59.329222
# 34  -98.102582  18.773105    293.203202    309.738769
# 35   78.284794  13.983935     74.786570     75.962944
# 36  116.776808   5.227788    199.171008    205.097446
# 37  -39.220755  11.644131    320.635357    308.245682
# 38  135.082814   4.695386    111.918462    120.334661
# 39  130.325894  12.097745    230.064496    237.940547
# 40  121.585536   6.121027    252.838518    252.794464
# 41   77.315744   3.308226     94.831956     95.846405
# 42  131.726300   2.500827     46.883967     49.430358
# 43   -1.182282   3.577351    230.619130    234.246175
# 44   14.657390  15.479491    409.144186    447.496224
# 45  -23.735074   9.327809    305.349838    327.555717
# 46   90.911595   4.148657    857.189496    895.832471
# 47  -95.129803  21.046280    353.196670    358.934164
# 48  -54.935250  12.916603     79.481858     81.191264
# 49   58.104174   1.664895     34.246392     34.403355
#
#                                              cov_list  \
# 0   [[0.00021241411217716384, 8.694810648803102e-0...
# 1   [[0.00021241411217716384, 8.694810648803102e-0...
# 2   [[0.00021241411217716384, 8.694810648803102e-0...
# 3   [[0.00021241411217716384, 8.694810648803102e-0...
# 4   [[0.00021241411217716384, 8.694810648803102e-0...
# 5   [[0.00021241411217716384, 8.694810648803102e-0...
# 6   [[0.00021241411217716384, 8.694810648803102e-0...
# 7   [[0.00021241411217716384, 8.694810648803102e-0...
# 8   [[0.00021241411217716384, 8.694810648803102e-0...
# 9   [[0.00021241411217716384, 8.694810648803102e-0...
# 10  [[0.00021241411217716384, 8.694810648803102e-0...
# 11  [[0.00021241411217716384, 8.694810648803102e-0...
# 12  [[0.00021241411217716384, 8.694810648803102e-0...
# 13  [[0.00021241411217716384, 8.694810648803102e-0...
# 14  [[0.00021241411217716384, 8.694810648803102e-0...
# 15  [[0.00021241411217716384, 8.694810648803102e-0...
# 16  [[0.00021241411217716384, 8.694810648803102e-0...
# 17  [[0.00021241411217716384, 8.694810648803102e-0...
# 18  [[0.00021241411217716384, 8.694810648803102e-0...
# 19  [[0.00021241411217716384, 8.694810648803102e-0...
# 20  [[0.00021241411217716384, 8.694810648803102e-0...
# 21  [[0.00021241411217716384, 8.694810648803102e-0...
# 22  [[0.00021241411217716384, 8.694810648803102e-0...
# 23  [[0.00021241411217716384, 8.694810648803102e-0...
# 24  [[0.00021241411217716384, 8.694810648803102e-0...
# 25  [[0.00021241411217716384, 8.694810648803102e-0...
# 26  [[0.00021241411217716384, 8.694810648803102e-0...
# 27  [[0.00021241411217716384, 8.694810648803102e-0...
# 28  [[0.00021241411217716384, 8.694810648803102e-0...
# 29  [[0.00021241411217716384, 8.694810648803102e-0...
# 30  [[0.00021402660177942984, 9.05446470430586e-05...
# 31  [[0.00021402660177942984, 9.05446470430586e-05...
# 32  [[0.00021402660177942984, 9.05446470430586e-05...
# 33  [[0.00021402660177942984, 9.05446470430586e-05...
# 34  [[0.00021402660177942984, 9.05446470430586e-05...
# 35  [[0.00021402660177942984, 9.05446470430586e-05...
# 36  [[0.00021402660177942984, 9.05446470430586e-05...
# 37  [[0.00021402660177942984, 9.05446470430586e-05...
# 38  [[0.00021402660177942984, 9.05446470430586e-05...
# 39  [[0.00021402660177942984, 9.05446470430586e-05...
# 40  [[0.00021402660177942984, 9.05446470430586e-05...
# 41  [[0.00021402660177942984, 9.05446470430586e-05...
# 42  [[0.00021402660177942984, 9.05446470430586e-05...
# 43  [[0.00021402660177942984, 9.05446470430586e-05...
# 44  [[0.00021402660177942984, 9.05446470430586e-05...
# 45  [[0.00021402660177942984, 9.05446470430586e-05...
# 46  [[0.00021402660177942984, 9.05446470430586e-05...
# 47  [[0.00021402660177942984, 9.05446470430586e-05...
# 48  [[0.00021402660177942984, 9.05446470430586e-05...
# 49  [[0.00021402660177942984, 9.05446470430586e-05...
#
#                                           return_list
# 0   tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 1   tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 2   tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 3   tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 4   tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 5   tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 6   tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 7   tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 8   tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 9   tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 10  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 11  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 12  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 13  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 14  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 15  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 16  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 17  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 18  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 19  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 20  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 21  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 22  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 23  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 24  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 25  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 26  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 27  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 28  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 29  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 30  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 31  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 32  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 33  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 34  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 35  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 36  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 37  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 38  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 39  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 40  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 41  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 42  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 43  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 44  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 45  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 46  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 47  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 48  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...
# 49  tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJF...

# %%
df['return_list'].values[0]
# Out:
# tic         ASIANPAINT.NS  AXISBANK.NS  BAJAJFINSV.NS  BAJFINANCE.NS  \
# date
# 2011-01-04      -0.013341    -0.014404      -0.004677      -0.006172
# 2011-01-05       0.015620    -0.027486      -0.007369      -0.004141
# 2011-01-06      -0.010762    -0.003852      -0.022055      -0.012545
# 2011-01-07      -0.025882    -0.019298      -0.019032      -0.042250
# 2011-01-10      -0.035306    -0.020341      -0.017046      -0.024028
# ...                   ...          ...            ...            ...
# 2012-01-04       0.008540     0.012656      -0.041036      -0.012481
# 2012-01-05      -0.001215     0.026528       0.005379       0.002891
# 2012-01-06      -0.004155    -0.019698       0.002972      -0.028087
# 2012-01-09       0.005694     0.005507       0.017425       0.033983
# 2012-01-10      -0.007176     0.042589       0.017476       0.028194
#
# tic         BHARTIARTL.NS  HCLTECH.NS  HDFCBANK.NS  HINDUNILVR.NS  \
# date
# 2011-01-04      -0.008209    0.015413    -0.018804       0.024749
# 2011-01-05      -0.020763    0.024287    -0.015924       0.014958
# 2011-01-06       0.012034    0.011326     0.008470      -0.015198
# 2011-01-07      -0.041620   -0.026062    -0.025046      -0.024006
# 2011-01-10       0.001773   -0.000752    -0.051642      -0.012937
# ...                   ...         ...          ...            ...
# 2012-01-04      -0.034295    0.037699     0.009450      -0.030641
# 2012-01-05      -0.005630   -0.008724     0.000790      -0.005310
# 2012-01-06      -0.040215    0.006751     0.021751       0.008771
# 2012-01-09      -0.030555   -0.006227     0.005295      -0.008442
# 2012-01-10       0.030894    0.011929     0.008778       0.005083
#
# tic         ICICIBANK.NS  INDUSINDBK.NS  ...  RELIANCE.NS   SBIN.NS  \
# date                                     ...
# 2011-01-04     -0.035638      -0.033629  ...     0.020368 -0.030651
# 2011-01-05     -0.031430      -0.026198  ...    -0.001207 -0.015499
# 2011-01-06     -0.014869      -0.020679  ...     0.009110 -0.026288
# 2011-01-07     -0.004035      -0.055966  ...    -0.018607 -0.008179
# 2011-01-10     -0.033549      -0.029099  ...    -0.029989 -0.020704
# ...                  ...            ...  ...          ...       ...
# 2012-01-04      0.023835       0.002267  ...    -0.011730 -0.005628
# 2012-01-05      0.006729       0.016451  ...    -0.023250 -0.002123
# 2012-01-06      0.004812      -0.025288  ...     0.025804 -0.011640
# 2012-01-09     -0.005188       0.019718  ...    -0.015748 -0.021222
# 2012-01-10      0.035705       0.062080  ...     0.042407  0.039914
#
# tic         SUNPHARMA.NS  TATAMOTORS.NS  TATASTEEL.NS    TCS.NS  TECHM.NS  \
# date
# 2011-01-04      0.005335      -0.007681     -0.013281 -0.011485  0.046301
# 2011-01-05     -0.003776      -0.012015     -0.019793  0.012404 -0.021555
# 2011-01-06      0.024485      -0.016994      0.003451  0.011001  0.001784
# 2011-01-07     -0.013300      -0.056146     -0.032270 -0.024793 -0.030349
# 2011-01-10     -0.033141      -0.011343     -0.015955 -0.010283 -0.020984
# ...                  ...            ...           ...       ...       ...
# 2012-01-04      0.003604       0.037381      0.005804 -0.020541  0.007417
# 2012-01-05     -0.002793       0.004473     -0.003710 -0.000852 -0.014973
# 2012-01-06      0.000200       0.007422      0.002896 -0.002219  0.006047
# 2012-01-09      0.011101      -0.014735     -0.005225  0.001667  0.008348
# 2012-01-10      0.021464       0.022433      0.027643 -0.005080  0.013826
#
# tic         TITAN.NS  ULTRACEMCO.NS  WIPRO.NS
# date
# 2011-01-04 -0.007839       0.002298  0.003312
# 2011-01-05 -0.004565      -0.016189  0.002063
# 2011-01-06 -0.016986      -0.057527  0.001442
# 2011-01-07 -0.046698      -0.022852 -0.019328
# 2011-01-10 -0.035255       0.007796 -0.025894
# ...              ...            ...       ...
# 2012-01-04 -0.009747      -0.028707  0.004202
# 2012-01-05 -0.007593       0.007181 -0.007890
# 2012-01-06 -0.020119       0.000435 -0.022171
# 2012-01-09  0.015327       0.000999 -0.011337
# 2012-01-10  0.030191       0.011461  0.005982
#
# [252 rows x 30 columns]

# %%
print(df.shape)

hist_vol=[]
for i in range(len(df['return_list'])):
  returns = df['return_list'].values[i].std()
  hist_vol.append(returns)
print(len(hist_vol))
# Out:
# (97200, 18)
# 97200

# %%
hist_vol= np.array(hist_vol)
# print(hist_vol.shape)
# print(hist_vol)
hist_vol= pd.DataFrame(hist_vol, df['date'])
# print(hist_vol.shape)
# print(df)
# df.to_csv('sensex_data.csv')
# hist_vol.to_csv('sensex_hist_vol.csv')
# from google.colab import files
# files.download('sensex_data.csv')
# files.download('sensex_hist_vol.csv')

# %%
# df= pd.read_csv("sensex_data.csv")
# hist_vol= pd.read_csv("sensex_hist_vol.csv")

# %% [markdown]
# <a id='4'></a>
# # **Part 5. Design Environment**
#
# We model portfolio optimization as a **Constrained Markov Decision Process (CMDP)**, ensuring **maximum returns while controlling risk**. The **state** includes stock prices, indicators, and risk metrics. The **action** is portfolio allocation, adjusting stock weights within constraints. **Rewards** maximize returns, while a **cost function** penalizes excessive risk. **Deep Deterministic Policy Gradient (DDPG) with Augmented Lagrangian Multiplier (ALM)** trains the agent:
# ✅ **Actor** optimizes allocations.
# ✅ **Critic** evaluates returns.
# ✅ **Cost network** estimates risk.
# ✅ **Lagrangian multiplier** enforces constraints.
# This ensures **risk-aware, reinforcement learning-based trading**, scalable to real markets.

# %%
# %%capture
# !pip install shimmy
# !pip install stable_baselines3
# !pip install gym
# Out:
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from shimmy) (2.0.2)
# Requirement already satisfied: gymnasium>=1.0.0a1 in /usr/local/lib/python3.11/dist-packages (from shimmy) (1.1.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy) (4.13.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy) (0.0.4)
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Installing collected packages: shimmy
# Successfully installed shimmy-2.0.0
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.1.1)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.6.0+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable_baselines3) (4.13.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3) (3.0.2)
# Downloading stable_baselines3-2.6.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable_baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable_baselines3-2.6.0
# Requirement already satisfied: gym in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from gym) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym) (3.1.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym) (0.0.8)

# %%
import numpy as np
import pandas as pd
from gym.utils import seeding
import gym
from gym import spaces
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv

# %% [markdown]
# ## Training data split: 2009-01-01 to 2020-07-01

# %%
TRAIN_START_DATE = '2011-01-01'
TRAIN_END_DATE = '2021-12-31'

# TRAIN_END_DATE = '2012-12-01'

Val_START_DATE = '2022-01-01'
VAL_END_DATE =  '2022-12-31'
TRADE_START_DATE = '2023-01-01'
TRADE_END_DATE = '2025-02-28'
# print(df[30:])
# hist_vol = hist_vol.reset_index(drop=True)

train = data_split(df, TRAIN_START_DATE,TRAIN_END_DATE)
hist_vol_train = hist_vol[TRAIN_START_DATE : TRAIN_END_DATE]

val = data_split(df, Val_START_DATE, VAL_END_DATE)
hist_vol_val=hist_vol[Val_START_DATE :VAL_END_DATE]

full_train = data_split(df, TRAIN_START_DATE, VAL_END_DATE)
hist_vol_full_train= hist_vol[TRAIN_START_DATE :VAL_END_DATE]


# full_train = data_split(df, TRAIN_START_DATE,TRAIN_END_DATE)
# hist_vol_full_train= hist_vol[TRAIN_START_DATE :TRAIN_END_DATE]

trade = data_split(df, TRADE_START_DATE,TRADE_END_DATE)
hist_vol_trade= hist_vol[TRADE_START_DATE  : TRADE_END_DATE]

print(full_train.shape)
# Out:
# (81210, 18)

# %% [markdown]
# Here is the definition of the environment.

# %%
class StockPortfolioEnv(gym.Env):
    """A single stock trading environment for OpenAI gym

    Attributes
    ----------
        df: DataFrame
            input data
        stock_dim : int
            number of unique stocks
        hmax : int
            maximum number of shares to trade
        initial_amount : int
            start money
        transaction_cost_pct: float
            transaction cost percentage per trade
        reward_scaling: float
            scaling factor for reward, good for training
        state_space: int
            the dimension of input features
        action_space: int
            equals stock dimension
        tech_indicator_list: list
            a list of technical indicator names
        turbulence_threshold: int
            a threshold to control risk aversion
        day: int
            an increment number to control date

    Methods
    -------
    _sell_stock()
        perform sell action based on the sign of the action
    _buy_stock()
        perform buy action based on the sign of the action
    step()
        at each step the agent will return actions, then
        we will calculate the reward, and return the next observation.
    reset()
        reset the environment
    render()
        use render to return other functions
    save_asset_memory()
        return account value at each time step
    save_action_memory()
        return actions/positions at each time step


    """
    metadata = {'render.modes': ['human']}

    def __init__(self,
                df,
                stock_dim,
                hmax,
                initial_amount,
                transaction_cost_pct,
                reward_scaling,
                state_space,
                action_space,
                tech_indicator_list,
                turbulence_threshold=None,
                lookback=252,
                day = 0, hist_vol= None):

        self.day = day
        self.lookback=lookback
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.transaction_cost_pct =transaction_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list
        self.hist_vol=hist_vol
        self.DSR_A = 0.0
        self.DSR_B = 0.0

         # action_space normalization and shape is self.stock_dim
        self.action_space = spaces.Box(low = 0, high = 1,shape = (self.action_space,))

        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape = (self.state_space+1 + len(self.tech_indicator_list), self.state_space))



        self.data = self.df.loc[self.day,:]
        self.covs = self.data['cov_list'].values[0]




        self.state = np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        # print(" state  :: " , self.day ,self.state.shape, self.state)
        # print(" hist_ vol  :: " , self.day , type(self.hist_vol), self.hist_vol)

        hist_volll = self.hist_vol.values[self.day,:]
        # Concatenate along axis=0

        self.state = np.concatenate([self.state, hist_volll.reshape(1,-1) ], axis=0)



        # print("states - " , self.state.shape)

        self.terminal = False
        self.turbulence_threshold = turbulence_threshold
        # initalize state: inital portfolio return + individual stock return + individual weights
        self.portfolio_value = self.initial_amount

        # memorize portfolio value each step
        self.asset_memory = [self.initial_amount]
        # memorize portfolio return each step
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]]



    def step(self, actions):
      print(f" the len of the df is  {len(self.df.index.unique())}  and the current day is :  {self.day } and  if  terminal is  : { self.day >= len(self.df.index.unique()) - 1 }")
      self.terminal = self.day >= len(self.df.index.unique()) - 1

      if self.terminal:
          # print("=================================")
          # print("begin_total_asset:{}".format(self.asset_memory[0]))
          # print("end_total_asset:{}".format(self.portfolio_value))
          # return self.state, self.reward, self.terminal, {}


          df = pd.DataFrame(self.portfolio_return_memory)
          df.columns = ['daily_return']
          # plt.plot(df.daily_return.cumsum(),'r')
          # plt.savefig('results/cumulative_reward.png')
          # plt.close()

          # plt.plot(self.portfolio_return_memory,'r')
          # plt.savefig('results/rewards.png')
          # plt.close()

          print("=================================")
          print("begin_total_asset:{}".format(self.asset_memory[0]))
          print("end_total_asset:{}".format(self.portfolio_value))

          df_daily_return = pd.DataFrame(self.portfolio_return_memory)
          df_daily_return.columns = ['daily_return']
          if df_daily_return['daily_return'].std() !=0:
            sharpe = (252**0.5)*df_daily_return['daily_return'].mean()/ \
                    df_daily_return['daily_return'].std()
            print("Sharpe: ",sharpe)
          print("=================================")


          return self.state, self.reward, self.terminal,{}
      else:
          last_day_memory = self.data
          weights = self.softmax_normalization(actions)  # Ensure valid portfolio weights
          self.actions_memory.append(weights)

          # Load next state
          self.day = self.day+ 1
          self.data = self.df.loc[self.day, :]
          self.covs = self.data['cov_list'].values[0]
          self.state = np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
          hist_voll= self.hist_vol.values[self.day,:]
          self.state = np.concatenate([self.state, hist_voll.reshape(1,-1) ], axis=0)

          # Portfolio Value Update
          portfolio_return = sum(((self.data.close.values / last_day_memory.close.values) - 1) * weights)
          new_portfolio_value = self.portfolio_value * (1 + portfolio_return)

          # Calculate Transaction Fee
          phi = 0.0025  # 0.25% transaction cost
          # Reshape portfolio_value to match dimensions of other arrays
          portfolio_value_reshaped = np.repeat(self.portfolio_value, len(weights))
          transaction_fee = phi * sum(
              abs(weights * new_portfolio_value * last_day_memory.close.values / self.data.close.values
                  - self.actions_memory[-2] * portfolio_value_reshaped)  # Use portfolio_value_reshaped
          )

          # Reward Calculation
          self.reward = (new_portfolio_value - self.portfolio_value) - transaction_fee  # r_t = u_t - u_t-1 - fee_t

          # Update portfolio value
          self.portfolio_value = new_portfolio_value

          # Save to memory
          self.portfolio_return_memory.append(portfolio_return)
          self.asset_memory.append(new_portfolio_value)
          self.date_memory.append(self.data.date.unique()[0])

          return self.state, self.reward, self.terminal, {}
    ##############################################




    def reset(self):
        self.asset_memory = [self.initial_amount]
        self.day = 0

        # returns = self.df['return_list'].values[0]
        # hist_vol = returns.rolling(window=30).std()
        # hist_vol.fillna(0, inplace=True)
        # hist_vol = hist_vol.iloc[self.day,:]


        self.data = self.df.loc[self.day,:]
        # load states
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        # print(self.hist_vol)
        # self.hist_vol= self.hist_vol[self.day,]
        # Concatenate along axis=0

        hist_voll= self.hist_vol.values[self.day,:]
        self.state = np.concatenate([self.state, hist_voll.reshape(1,-1)], axis=0)
        # Concatenate along axis=0





        # print(" reset -- ev  --state -", self.state.shape)
        # print(" reset -- ev -- state - ", self.state)
        # print(" reset -- ev-- cov - ", self.state[:30, :].shape)
        # print(" reset -- ev-- his vol- ", self.state[:-1, :].shape)
        # print(" reset -- ev-- his vol- ", self.state[-1:, :])
        self.portfolio_value = self.initial_amount
        #self.cost = 0
        #self.trades = 0
        self.DSR_A = 0.0
        self.DSR_B = 0.0
        self.terminal = False
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]]
        return self.state

    def render(self, mode='human'):
        return self.state

    def softmax_normalization(self, actions):
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator/denominator
        return softmax_output


    def apply_dirichlet_noise(self, actions, alpha=0.1):
      """
      Apply Dirichlet noise to actions to encourage exploration.

      Args:
      - actions (np.array): Original action values from the RL model.
      - alpha (float): Dirichlet concentration parameter. Lower values = more noise.

      Returns:
      - np.array: Modified action values with noise, ensuring sum = 1.
      """
      noise = np.random.dirichlet([alpha] * len(actions))  # Sample from Dirichlet distribution
      noisy_actions = 0.75 * actions + 0.25 * noise  # Blend original actions with noise
      return noisy_actions / noisy_actions.sum()  # Normalize to ensure sum = 1




    def save_asset_memory(self):
        date_list = self.date_memory
        portfolio_return = self.portfolio_return_memory
        #print(len(date_list))
        #print(len(asset_list))
        df_account_value = pd.DataFrame({'date':date_list,'daily_return':portfolio_return})
        return df_account_value

    def save_action_memory(self):
        # date and close price length must match actions length
        date_list = self.date_memory
        df_date = pd.DataFrame(date_list)
        df_date.columns = ['date']

        action_list = self.actions_memory
        df_actions = pd.DataFrame(action_list)
        df_actions.columns = self.data.tic.values
        df_actions.index = df_date.date
        #df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

    def calculate_DSR(self, R):
      eta = 0.004
      delta_A = R - self.DSR_A
      delta_B = R**2 - self.DSR_B
      Dt = (self.DSR_B*delta_A - 0.5*self.DSR_A*delta_B) / ((self.DSR_B-self.DSR_A**2)**(3/2) + 1e-6)
      self.DSR_A = self.DSR_A + eta*delta_A
      self.DSR_B = self.DSR_B + eta*delta_B
      return(Dt)

# %%
stock_dimension = len(train.tic.unique())

state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 30, State Space: 30

# %%
# print(INDICATORS)
TURBULENCE_THRESHOLD= 0.0020

env_kwargs_train = {
    "hmax": 100,
    "initial_amount": 1000000,
    "transaction_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4,
    "hist_vol":hist_vol_train,
    'turbulence_threshold': TURBULENCE_THRESHOLD

}
# print(hist_vol_val,"  ddddd ")
env_kwargs_val = {
    "hmax": 100,
    "initial_amount": 1000000,
    "transaction_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4,
    "hist_vol":hist_vol_val,
    "turbulence_threshold": TURBULENCE_THRESHOLD
}

env_kwargs_full = {
    "hmax": 100,
    "initial_amount": 1000000,
    "transaction_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4,
    "hist_vol":hist_vol_full_train,
    "turbulence_threshold": TURBULENCE_THRESHOLD
}

env_kwargs_trade = {
    "hmax": 100,
    "initial_amount": 1000000,
    "transaction_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4,
    "hist_vol":hist_vol_trade,
    "turbulence_threshold": TURBULENCE_THRESHOLD
}

# %%
e_train_gym = StockPortfolioEnv(df = train, **env_kwargs_train)
env_train, _ = e_train_gym.get_sb_env()

e_val_gym = StockPortfolioEnv(df = val, **env_kwargs_val)
env_val, _ = e_val_gym.get_sb_env()

e_train_full_gym = StockPortfolioEnv(df = full_train, **env_kwargs_full)
env_full_train, _ = e_train_full_gym.get_sb_env()

e_trade_gym = StockPortfolioEnv(df = trade, **env_kwargs_trade)
env_trade, _ = e_trade_gym.get_sb_env()
print("done")
# Out:
# done
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * DDPG-with ALM

# %%
import random
from collections import deque

class Memory:
    def __init__(self, max_size):
        self.buffer = deque(maxlen=max_size)

    def push(self, state, action, reward, next_state, done):
        experience = (state, action, np.array([reward]), next_state, done)

        self.buffer.append(experience)

    def sample(self, batch_size):
        state_batch = []
        action_batch = []
        reward_batch = []
        next_state_batch = []
        done_batch = []

        batch = random.sample(self.buffer, batch_size)

        for experience in batch:
            state, action, reward, next_state, done = experience
            state_batch.append(state)
            action_batch.append(action)
            reward_batch.append(reward)
            next_state_batch.append(next_state)
            done_batch.append(done)

        state_batch = np.array(state_batch)
        action_batch = np.array(action_batch)
        reward_batch = np.array(reward_batch)
        next_state_batch = np.array(next_state_batch)

        return state_batch, action_batch, reward_batch, next_state_batch, done_batch

    def __len__(self):
        return len(self.buffer)

# %% [markdown]
# * using dirchilet noise instead.

# %%
import numpy as np


def Noise(action, action_space, kappa=10):
    """
    Apply Dirichlet noise for exploration in DDPG according to the paper.

    Args:
    - action (torch.Tensor): Original action values from the actor network.
    - action_space (gym.spaces.Box): Action space defining valid ranges.
    - kappa (float): Controls exploration variance. Higher kappa = less noise.

    Returns:
    - np.array: Modified action values with Dirichlet noise, ensuring sum = 1.
    """

    try:
        # Ensure actions are non-negative before applying Dirichlet noise
        action = torch.clamp(action, min=0.0)

        # Convert actions to numpy array for Dirichlet sampling
        action_np = action.detach().cpu().numpy()

        # Compute shape parameter: υ = κ * a
        upsilon = kappa * action_np

        # Ensure upsilon is positive and correctly shaped
        upsilon = np.maximum(upsilon, 1e-6)  # Prevent zero or negative values
        upsilon = upsilon.flatten()  # Ensure it's a 1D array

        # Debugging: Check upsilon values
        if np.any(upsilon <= 0):
            raise ValueError(f"Dirichlet parameters must be positive. Found: {upsilon}")

        # Sample ϵ from Dirichlet distribution
        epsilon = np.random.dirichlet(upsilon)

        # Compute final action: a' = a + sg(ϵ - a)
        noisy_action = action_np + (epsilon - action_np)

        # Apply StopGradient (detach the noise term)
        noisy_action = action_np + torch.tensor(noisy_action - action_np, requires_grad=False).numpy()

        # Clip extreme values to prevent instability
        noisy_action = np.clip(noisy_action, 0.0, 1.0)

        # Ensure sum = 1 for valid portfolio allocation
        noisy_action = noisy_action / noisy_action.sum()

        return noisy_action

    except ValueError as ve:
        print(f"ValueError in Dirichlet noise function: {ve}")
    except Exception as e:
        print(f"Unexpected error in Dirichlet noise function: {e}")

    # Return the original action if an error occurs
    return action.detach().cpu().numpy()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F


class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, hidden_dim, num_layers, act_fn, dr):
        super(Actor, self).__init__()

        layers = []

        if act_fn == 'relu': activation_fn = nn.ReLU()
        if act_fn == 'tanh': activation_fn = nn.Tanh()
        if act_fn == 'sigmoid': activation_fn = nn.Sigmoid()
        # print("Params Dictionary:", self.params)
        hidden_dim = int(hidden_dim)
        num_layers = int(num_layers)
        action_dim = int(action_dim)
        state_dim = int(state_dim)

        # print("state_dim:", state_dim)
        # print("action_dim:", action_dim)
        # print("hidden_dim:", hidden_dim)
        # print("num_layers:", num_layers)
        # print("act_fn:", act_fn)
        # print("dr:", dr)
        # print(f"state_dim: {state_dim}, type: {type(state_dim)}")
        # print(f"action_dim: {action_dim}, type: {type(action_dim)}")
        # print(f"hidden_dim: {hidden_dim}, type: {type(hidden_dim)}")

        # Add input layer

        layers.append(nn.Flatten())
        layers.append(nn.Linear(state_dim, hidden_dim))
        layers.append(activation_fn)
        layers.append(nn.Dropout(p=dr))

        # Add hidden layers
        for _ in range(num_layers - 2):  # -2 because we already added the input and output layers
            layers.append(nn.Linear(hidden_dim, hidden_dim))
            layers.append(activation_fn)
            layers.append(nn.Dropout(p=dr))

        # Add output layer
        layers.append(nn.Linear(hidden_dim, action_dim))
        # layers.append(nn.Dropout(p=dr))

        # Create the sequential model
        self.model = nn.Sequential(*layers)

    def forward(self, state):

        x = self.model(state)
        x = torch.tanh(x)
        # print(" actor  Network forward (((((((((((((((((((((((((((((((((((((())))))))))))))))))))))))))))))))))))))")
        return x


class Critic(nn.Module):
    def __init__(self, state_dim, action_dim, hidden_dim, num_layers, act_fn, dr):
        super(Critic, self).__init__()

        layers = []

        if act_fn == 'relu': activation_fn = nn.ReLU()
        if act_fn == 'tanh': activation_fn = nn.Tanh()
        if act_fn == 'sigmoid': activation_fn = nn.Sigmoid()
        hidden_dim = int(hidden_dim)
        num_layers = int(num_layers)
        action_dim = int(action_dim)
        state_dim = int(state_dim)

        # print("state_dim:", state_dim)
        # print("action_dim:", action_dim)
        # print("hidden_dim:", hidden_dim)
        # print("num_layers:", num_layers)
        # print("act_fn:", act_fn)
        # print("dr:", dr)
        # print(f"state_dim: {state_dim}, type: {type(state_dim)}")
        # print(f"action_dim: {action_dim}, type: {type(action_dim)}")
        # print(f"hidden_dim: {hidden_dim}, type: {type(hidden_dim)}")


        # Add input layer
        layers.append(nn.Linear(state_dim + action_dim, hidden_dim))
        layers.append(activation_fn)
        layers.append(nn.Dropout(p=dr))

        # Add hidden layers
        for _ in range(num_layers - 2):  # -2 because we already added the input and output layers
            layers.append(nn.Linear(hidden_dim, hidden_dim))
            layers.append(activation_fn)
            layers.append(nn.Dropout(p=dr))

        # Add output layer
        # layers.append(nn.Dropout(p=dr))
        layers.append(nn.Linear(hidden_dim, 1))

        # Create the sequential model
        self.model = nn.Sequential(*layers)

    def forward(self, state, action):
        """
        Forward pass of the Critic network.

        Args:
        - state (torch.Tensor): State tensor.
        - action (torch.Tensor): Action tensor.

        Returns:
        - Q-value estimation.
        """

        # 🔍 Print debug info
        # print("Critic Network forward (((((((((((((((((((((((((((((((((((((())))))))))))))))))))))))))))))))))))))")
        # print(f"State shape before reshape: {state.shape}, Action shape before reshape: {action.shape}")

        # 🔄 Flatten state if it has more than 2 dimensions (CNN case)
        if state.dim() > 2:
            state = state.view(state.shape[0], -1)  # Convert to (batch_size, features)

        # 🔄 Ensure action is 2D
        if action.dim() > 2:
            action = action.view(action.shape[0], -1)  # Convert to (batch_size, action_dim)

        # 🔍 Print final shapes
        # print(f"State shape after reshape: {state.shape}, Action shape after reshape: {action.shape}")

        # ✅ Now both state and action are 2D → Safe to concatenate
        x = torch.cat([state, action], dim=1)

        # Forward pass through Critic layers
        x = self.model(x)

        return x





class CostNetwork(nn.Module):
    """
    Neural network for estimating portfolio risk (cost).
    """
    def __init__(self, state_dim, action_dim, hidden_dim):
        super(CostNetwork, self).__init__()

        state_dim=int(state_dim)
        action_dim=int(action_dim)
        hidden_dim=int(hidden_dim)
        # print("state_dim:", state_dim)
        # print("action_dim:", action_dim)
        # print("hidden_dim:", hidden_dim)

        self.model = nn.Sequential(
            nn.Linear(state_dim + action_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1)  # Outputs cost estimate
        )

    def forward(self, state, action):
        """
        Forward pass for the cost network.

        Computes:
        c_wv(s, a) = E[VaR(s, a)]  (Eq. 19 in the paper)

        Args:
        - state (torch.Tensor): State tensor with shape [batch_size, *]
        - action (torch.Tensor): Action tensor with shape [batch_size, action_dim]

        Returns:
        - Cost estimation (torch.Tensor)
        """

        # print(" cost network forward ((((((((((((((((((((((((((((((((((((((()))))))))))))))))))))))))))))))))))))))")
        # 🔍 Print debug info to check tensor shapes
        # print("state :: ", type(state) , state.shape)
        # print("action :: ", type(action) , action.shape)
        # 🔄 Flatten state if it has more than 2 dimensions
        if state.dim() > 2:
            state = state.view(state.shape[0], -1)  # Reshape to [batch_size, flattened_features]

        # 🔄 Ensure action is 2D
        if action.dim() > 2:
            action = action.view(action.shape[0], -1)  # Reshape to [batch_size, action_dim]

        # 🔍 Print final shapes
        # print(f"State shape after reshape: {state.shape}, Action shape after reshape: {action.shape}")

        # ✅ Now both state and action are 2D → Safe to concatenate
        x = torch.cat([state, action], dim=1)
        # Forward pass through the Cost network
        return self.model(x)

# %%
#device = 'cpu'
# Set the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from scipy.stats import norm  # For z-score

class DDPGagent:
    def __init__(self, env, params, max_memory_size=50000):
        """
        Initialize the DDPG agent with:
        - Actor-Critic Networks
        - Cost Network for risk constraints
        - Target Networks for stability
        - Lagrange multiplier for enforcing constraints
        """

        # print(params)
        print(" DDPG AGEnt Class- ++++++++++++++++++++++++++++++++++++++++++")

        # 1️⃣ Define State & Action Space Dimensions
        self.data = env.envs[0].df
        curr_state= env.envs[0].state
        # print("states_ ddpg init ::", curr_state.shape)
        actions = env.action_space.shape[0]

        # print("actions ::", actions)

        self.num_states = env.observation_space.shape[0] * env.observation_space.shape[1]
        self.num_actions = env.action_space.shape[0]
        self.gamma = params['gamma']  # Discount factor (γ)
        self.tau = params['tau']  # Soft update factor (τ)
        self.batch_size = int(params['batch_size'])
        self.env = env
        self.eta = params['eta']


        # 2️⃣ Initialize Networks
        self.actor = Actor(self.num_states, self.num_actions, params['Ahidden_dim'],
                           params['Anum_layers'], params['Aact_fn'], params['Adr']).to(device)
        self.actor_target = Actor(self.num_states, self.num_actions, params['Ahidden_dim'],
                                  params['Anum_layers'], params['Aact_fn'], params['Adr']).to(device)

        self.critic = Critic(self.num_states, self.num_actions, params['Chidden_dim'],
                             params['Cnum_layers'], params['Cact_fn'], params['Cdr']).to(device)
        self.critic_target = Critic(self.num_states, self.num_actions, params['Chidden_dim'],
                                    params['Cnum_layers'], params['Cact_fn'], params['Cdr']).to(device)

        # 3️⃣ Initialize Cost Network for Constrained Reinforcement Learning
        self.cost_network = CostNetwork(self.num_states, self.num_actions, params['Chidden_dim']).to(device)
        self.cost_target = CostNetwork(self.num_states, self.num_actions, params['Chidden_dim']).to(device)

        # Copy weights to target networks
        for target_param, param in zip(self.actor_target.parameters(), self.actor.parameters()):
            target_param.data.copy_(param.data)

        for target_param, param in zip(self.critic_target.parameters(), self.critic.parameters()):
            target_param.data.copy_(param.data)

        for target_param, param in zip(self.cost_target.parameters(), self.cost_network.parameters()):
            target_param.data.copy_(param.data)

        # 4️⃣ Training Setup
        self.memory = Memory(max_memory_size)
        self.critic_criterion = nn.MSELoss()
        self.cost_criterion = nn.MSELoss()
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=params['alr'])
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=params['clr'])
        self.cost_optimizer = optim.Adam(self.cost_network.parameters(), lr=params['clr'])

        # 5️⃣ Initialize Lagrange Multiplier for Constraint Enforcement
        self.lambda_ = 0.01
        self.rho = 0.01  # Step size for updating lambda
        self.violations= 0
        self.zeta= env.envs[0].turbulence_threshold


    def get_action(self, state):
        state_tensor = torch.FloatTensor(state).to(device)
        action = self.actor.forward(state_tensor).detach().cpu()

        #action = action.detach().numpy()
        return action



    def VaR(self, states, actions, confidence_level=0.95):
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        actions = actions.to(device)
        states = states.to(device)  # assume actions is already on the correct device

        batch_size = states.shape[0]  # ✅ Do NOT use `.to(device)` here
        num_assets = 30

        states = states.squeeze(1).to(device)  # [batch_size, 38, 30]
        states_n = states  # already squeezed

        cov_matrix = states[:, :num_assets, :].to(device)  # [batch_size, 30, 30]
        hist_volatility = states_n[:, -1, :].to(device)  # [batch_size, 30]

        z_score = torch.tensor(1.645, device=device)  # ✅ place tensor on the same device
        individual_VaR = z_score * hist_volatility  # [batch_size, 30]

        VaR_portfolio = torch.zeros(batch_size, device=device)  # ✅ directly initialize on device

        for i in range(num_assets):
            for j in range(num_assets):
                VaR_portfolio = VaR_portfolio + (
                    actions[:, i] * individual_VaR[:, i] *
                    actions[:, j] * individual_VaR[:, j] * cov_matrix[:, i, j]
                )

        return VaR_portfolio







    def compute_cost_target(self, states, actions, next_states, dones):
        """
        Compute the target cost using the Bellman equation.

        Equation (20):
        c_{w_v}(s, a) = VaR(s, a) + \eta (1 - d) c'_{w_v'}(s', a')
        """
        next_actions = self.actor_target.forward(next_states)  # π'(s')
        next_cost = self.cost_target.forward(next_states, next_actions.detach())  # c'_wv'(s', a')
        cost_target = self.VaR(next_states, next_actions) + self.eta * next_cost
        return cost_target

    def update(self):
        """
        Perform one update step for the Actor, Critic, and Cost networks.
        """

        # 1️⃣ Sample a batch from the Replay Buffer
        states, actions, rewards, next_states, dones = self.memory.sample(self.batch_size)


        # print(" update states : ", type(states),  states.shape,  " action ", action.shape, type(action) )

        # Remove the singleton dimension at dim=1
        # states_n = states.squeeze(1)  # shape: (224, 38, 30)

        # # Now slicing makes sense
        # cov_mat = states_n[:, :30, :]                  # Shape: (224, 30, 30)
        # histrical_volatility = states_n[:, -1, :]


        # print("ddpg update - states_n ::", states_n.shape)
        # print("ddpg update - cov_mat_n ::", cov_mat.shape)
        # print("ddpg update - histrical_volatility_n ::", histrical_volatility.shape)

        # print("ddpg update - states_n ::", states_n)
        # print("ddpg update - cov_mat_n ::", cov_mat)
        # print("ddpg update - histrical_volatility_n ::", histrical_volatility)


        # next_states_n = next_states.squeeze(1)  # Shape: [batch_size, 38, 30]
        # next_cov_mat = next_states_n[:, :30, :]  # Shape: [batch_size, 30, 30]
        # next_hist_volatility = next_states_n[:, -1, :]
        # print("ddpg update - next_states_n ::", next_states_n.shape)
        # print("ddpg update - next_cov_mat ::", next_cov_mat.shape)
        # print("ddpg update - histor vol :: " , next_hist_volatility.shape)
        # print("ddpg update - next_states_n ::", next_states_n)
        # print("ddpg update - next_cov_mat ::", next_cov_mat)
        # print("ddpg update - histor vol :: " , next_hist_volatility)







        states = torch.FloatTensor(states).to(device)
        actions = torch.FloatTensor(actions).to(device)
        rewards = torch.FloatTensor(rewards).to(device)
        next_states = torch.FloatTensor(next_states).to(device)
        dones = torch.FloatTensor(dones).to(device)

        # 4️⃣ Compute Target Q-Value using Bellman Equation (Eq. 5)
        # Q(s, a) = r + γQ'(s', π'(s'))
        Q_target = rewards + self.gamma  * self.critic_target.forward(next_states, self.actor_target.forward(next_states).detach())

        # 6️⃣ Compute Critic Loss (Eq. 6)
        # L = 1/N \sum (Q(s, a) - Q_target)^2
        # print(" critic loss calculation -start")
        critic_loss = self.critic_criterion(self.critic.forward(states, actions), Q_target.detach())

        # print("critic loss calculation end ")
        # 8️⃣ Compute Cost Network Loss (Eq. 21)
        # L_C = 1/N \sum (c_{w_v}(s, a) - VaR(s, a) - η (1 - d) c'_{w_v'}(s', a'))^2
        # print("cost loss calculation started ")
        cost_pred = self.cost_network.forward(states, actions)
        cost_target = self.compute_cost_target(states, actions, next_states, dones).detach()
        # print(" cost_ target :: " , cost_target)

        cost_loss = self.cost_criterion(cost_pred, cost_target)

        # print("cost loss calculation end ")
        # 🔟 Compute Actor Loss using Lagrangian method (Eq. 13)
        # L(w_π, λ) = -J_{w_π} + \sum \lambda_j C_{w_π, j} + \frac{\rho}{2} \sum (C_{w_π, j})^2

        # print("actor loss calculation started ")
        policy_loss = -self.critic.forward(states, self.actor.forward(states)).mean()
        constraint_penalty =  cost_target

        # print(" constraint penalty before :: ", constraint_penalty)
        # print(" constraint_penalty :::: " , constraint_penalty.shape, type(constraint_penalty))

        violations_count = (constraint_penalty > self.zeta).sum().item()  # Count how many elements violate the constraint
        # print(" violations ::: " , violations_count)
        # Update the number of violations
        self.violations  =  self.violations + violations_count


        constraint_penalty = torch.where(
            constraint_penalty <= self.zeta,
            torch.tensor(0.0, device=constraint_penalty.device, dtype=constraint_penalty.dtype),
            constraint_penalty - self.zeta
        )
        # print(" constraint penalty after :: ", constraint_penalty)

        quadratic_penalty = (self.rho / 2) * (constraint_penalty ** 2).mean().clone()
        constraint_penalty=(self.lambda_ * constraint_penalty).mean().clone()
        actor_loss = policy_loss + constraint_penalty + quadratic_penalty

        self.actor_optimizer.zero_grad()
        # print(" actor_ loss ",  actor_loss.shape)
        actor_loss = actor_loss.mean()
        actor_loss.backward()
        self.actor_optimizer.step()


        # print("actor update end ")



        # 1️⃣3️⃣ Soft Update of Target Networks (Eq. 14)
        # print("soft update - critic -")
        with torch.no_grad():
          for target_param, param in zip(self.critic_target.parameters(), self.critic.parameters()):
              target_param.data= param.data * self.tau + target_param.data * (1.0 - self.tau)

          for target_param, param in zip(self.actor_target.parameters(), self.actor.parameters()):
              target_param.data = param.data * self.tau + target_param.data * (1.0 - self.tau)

          for target_param, param in zip(self.cost_target.parameters(), self.cost_network.parameters()):
              target_param.data = param.data * self.tau + target_param.data * (1.0 - self.tau)




        # print(" soft updates end")

    def buffer_fill(self, buffer_size):
      state = self.env.reset()

      # print(" buffer fill ------ ")
      # print(" buffer fil state   --- ",  state.shape)
      # print("  buffer fill state  --- ", state)
      # print(" buffer --- fill -- cov mat", state[:, :30, :].shape)

      # print(" buffer fill -----hist vol", state[:, -1, :].shape)
      # print(" buffer fill -----hist vol", state[:, -1, :])

      for _ in range(buffer_size):
        action = self.get_action(state)
        action = Noise(action, self.env.action_space)
        new_state, reward, done, _ = self.env.step(action)
        self.memory.push(state, action, reward, new_state, done)

    def trade(self, val_env, e_val_gym):
      Reward = []
      state = val_env.reset()

      for i in range(len(e_val_gym.df.index.unique())):
        action = self.get_action(state)
        next_obs, reward, done, _ = val_env.step(action.detach().numpy())
        Reward.append(reward)

        if i == (len(e_val_gym.df.index.unique()) - 2):
          account_memory = val_env.env_method(method_name="save_asset_memory")
          actions_memory = val_env.env_method(method_name="save_action_memory")

        if done[0]:
          print("hit end!")
          break
        state = next_obs

      return account_memory, actions_memory, sum(Reward)
# Out:
# <>:120: DeprecationWarning: invalid escape sequence '\e'

# %%
#Calculate the Sharpe ratio
#This is our objective for tuning
def calculate_sharpe(df):
  #df['daily_return'] = df['account_value'].pct_change(1)
  if df['daily_return'].std() !=0:
    sharpe = (252**0.5)*df['daily_return'].mean()/ \
          df['daily_return'].std()
    return sharpe
  else:
    return 0

# %%
space = {
    'Ahidden_dim': hp.quniform('Ahidden_dim', 2, 512, 1),
    'Anum_layers': hp.quniform('Anum_layers', 1, 8, 1),
    'Chidden_dim': hp.quniform('Chidden_dim', 2, 512, 1),
    'Cnum_layers': hp.quniform('Cnum_layers', 1, 8, 1),

    'alr': hp.loguniform('alr', -8, -1),  # Actor learning rate
    'clr': hp.loguniform('clr', -8, -1),  # Critic learning rate
    'gamma': hp.uniform('gamma', 0.9, 0.99),  # Discount factor
    'tau': hp.uniform('tau', 0.08, 0.2),  # Soft target update rate
    'batch_size': hp.quniform('batch_size', 32, 256, 32),  # Mini-batch size

    'Aact_fn': hp.choice('Aact_fn', ['relu', 'tanh', 'sigmoid']),  # Actor activation
    'Adr': hp.uniform('Adr', 0, 0.5),  # Actor dropout
    'Cact_fn': hp.choice('Cact_fn', ['relu', 'tanh', 'sigmoid']),  # Critic activation
    'Cdr': hp.uniform('Cdr', 0, 0.5),  # Critic dropout


    'eta' : hp.uniform('eta', 0.01, 1),  # Exploration noise level
    # 🚀 **Newly Added Missing Hyperparameters**:
    # 'rho': hp.uniform('rho', 0.001, 0.1),  # Lagrange multiplier update step size
    # 'lambda_init': hp.uniform('lambda_init', 0.01, 1.0),  # Initial value of λ
    'buffer_size': hp.quniform('buffer_size', 10000, 1000000, 10000),  # Replay buffer size
    'noise_std': hp.uniform('noise_std', 0.01, 0.3),  # Exploration noise level
    'grad_clip': hp.uniform('grad_clip', 0.1, 10.0),  # Gradient clipping threshold
    'warmup_steps': hp.quniform('warmup_steps', 1000, 50000, 1000),  # Steps before training starts
    'reward_scaling': hp.uniform('reward_scaling', 0.1, 10.0)  # Reward scaling factor
}


def objective(params):
    print(params)
    # Convert hyperparameters to integers where necessary
    params['Ahidden_dim'] = int(params['Ahidden_dim'])
    params['Anum_layers'] = int(params['Anum_layers'])
    params['Chidden_dim'] = int(params['Chidden_dim'])
    params['Cnum_layers'] = int(params['Cnum_layers'])
    params['batch_size'] = int(params['batch_size'])
    params['buffer_size'] = int(params['buffer_size'])
    params['warmup_steps'] = int(params['warmup_steps'])

    model = DDPGagent(env_train, params)
    model.buffer_fill(500)
    model.update()

    account_memory, actions_memory, rewardd = model.trade(env_val, e_val_gym)
    print( f" the reward is :::::::    {rewardd}  " )

    sharpe = calculate_sharpe(account_memory[0])
    return -sharpe
    # return -reward[0]

# %%
best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals= 10 , trials=Trials()) #max_evals = 500
# Out:
# {'Aact_fn': 'tanh', 'Adr': 0.4593674917547349, 'Ahidden_dim': 114.0, 'Anum_layers': 4.0, 'Cact_fn': 'sigmoid', 'Cdr': 0.0002653436925116881, 'Chidden_dim': 336.0, 'Cnum_layers': 3.0, 'alr': 0.31127276152586664, 'batch_size': 128.0, 'buffer_size': 960000.0, 'clr': 0.018399242623809892, 'gamma': 0.9374861218269449, 'grad_clip': 4.265290985114307, 'noise_std': 0.09413422933216273, 'reward_scaling': 6.257622087880992, 'rho': 0.09230334360979263, 'tau': 0.08522154033783835, 'warmup_steps': 46000.0}
#  DDPG AGEnt Class- ++++++++++++++++++++++++++++++++++++++++++
#  the len of the df is  2458  and the current day is :  0 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  1 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  2 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  3 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  4 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  5 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  6 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  7 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  8 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  9 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  10 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  11 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  12 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  13 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  14 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  15 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  16 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  17 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  18 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  19 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  20 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  21 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  22 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  23 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  24 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  25 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  26 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  27 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  28 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  29 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  30 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  31 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  32 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  33 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  34 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  35 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  36 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  37 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  38 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  39 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  40 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  41 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  42 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  43 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  44 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  45 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  46 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  47 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  48 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  49 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  50 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  51 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  52 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  53 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  54 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  55 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  56 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  57 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  58 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  59 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  60 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  61 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  62 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  63 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  64 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  65 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  66 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  67 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  68 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  69 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  70 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  71 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  72 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  73 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  74 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  75 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  76 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  77 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  78 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  79 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  80 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  81 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  82 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  83 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  84 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  85 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  86 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  87 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  88 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  89 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  90 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  91 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  92 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  93 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  94 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  95 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  96 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  97 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  98 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  99 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  100 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  101 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  102 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  103 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  104 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  105 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  106 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  107 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  108 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  109 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  110 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  111 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  112 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  113 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  114 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  115 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  116 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  117 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  118 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  119 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  120 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  121 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  122 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  123 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  124 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  125 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  126 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  127 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  128 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  129 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  130 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  131 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  132 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  133 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  134 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  135 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  136 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  137 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  138 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  139 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  140 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  141 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  142 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  143 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  144 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  145 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  146 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  147 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  148 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  149 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  150 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  151 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  152 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  153 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  154 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  155 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  156 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  157 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  158 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  159 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  160 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  161 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  162 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  163 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  164 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  165 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  166 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  167 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  168 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  169 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  170 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  171 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  172 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  173 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  174 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  175 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  176 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  177 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  178 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  179 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  180 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  181 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  182 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  183 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  184 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  185 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  186 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  187 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  188 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  189 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  190 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  191 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  192 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  193 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  194 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  195 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  196 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  197 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  198 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  199 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  200 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  201 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  202 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  203 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  204 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  205 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  206 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  207 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  208 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  209 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  210 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  211 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  212 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  213 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  214 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  215 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  216 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  217 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  218 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  219 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  220 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  221 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  222 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  223 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  224 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  225 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  226 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  227 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  228 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  229 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  230 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  231 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  232 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  233 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  234 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  235 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  236 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  237 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  238 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  239 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  240 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  241 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  242 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  243 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  244 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  245 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  246 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  247 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  248 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  249 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  250 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  251 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  252 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  253 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  254 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  255 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  256 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  257 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  258 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  259 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  260 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  261 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  262 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  263 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  264 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  265 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  266 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  267 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  268 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  269 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  270 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  271 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  272 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  273 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  274 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  275 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  276 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  277 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  278 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  279 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  280 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  281 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  282 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  283 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  284 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  285 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  286 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  287 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  288 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  289 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  290 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  291 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  292 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  293 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  294 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  295 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  296 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  297 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  298 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  299 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  300 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  301 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  302 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  303 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  304 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  305 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  306 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  307 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  308 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  309 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  310 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  311 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  312 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  313 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  314 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  315 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  316 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  317 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  318 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  319 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  320 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  321 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  322 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  323 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  324 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  325 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  326 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  327 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  328 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  329 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  330 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  331 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  332 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  333 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  334 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  335 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  336 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  337 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  338 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  339 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  340 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  341 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  342 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  343 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  344 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  345 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  346 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  347 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  348 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  349 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  350 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  351 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  352 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  353 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  354 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  355 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  356 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  357 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  358 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  359 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  360 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  361 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  362 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  363 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  364 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  365 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  366 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  367 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  368 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  369 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  370 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  371 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  372 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  373 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  374 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  375 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  376 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  377 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  378 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  379 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  380 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  381 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  382 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  383 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  384 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  385 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  386 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  387 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  388 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  389 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  390 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  391 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  392 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  393 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  394 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  395 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  396 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  397 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  398 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  399 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  400 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  401 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  402 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  403 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  404 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  405 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  406 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  407 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  408 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  409 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  410 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  411 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  412 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  413 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  414 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  415 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  416 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  417 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  418 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  419 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  420 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  421 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  422 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  423 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  424 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  425 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  426 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  427 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  428 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  429 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  430 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  431 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  432 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  433 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  434 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  435 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  436 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  437 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  438 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  439 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  440 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  441 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  442 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  443 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  444 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  445 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  446 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  447 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  448 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  449 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  450 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  451 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  452 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  453 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  454 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  455 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  456 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  457 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  458 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  459 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  460 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  461 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  462 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  463 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  464 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  465 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  466 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  467 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  468 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  469 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  470 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  471 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  472 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  473 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  474 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  475 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  476 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  477 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  478 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  479 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  480 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  481 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  482 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  483 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  484 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  485 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  486 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  487 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  488 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  489 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  490 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  491 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  492 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  493 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  494 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  495 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  496 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  497 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  498 and  if  terminal is  : False
#  the len of the df is  2458  and the current day is :  499 and  if  terminal is  : False
#   0%|          | 0/10 [00:18<?, ?trial/s, best loss=?]
# <ipython-input-34-4a15697fa8e0>:179: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   dones = torch.FloatTensor(dones).to(device)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/loss.py:610: UserWarning: Using a target size (torch.Size([128, 128, 1])) that is different to the input size (torch.Size([128, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/loss.py:610: UserWarning: Using a target size (torch.Size([128, 128])) that is different to the input size (torch.Size([128, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
#  the len of the df is  248  and the current day is :  0 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  1 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  2 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  3 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  4 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  5 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  6 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  7 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  8 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  9 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  10 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  11 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  12 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  13 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  14 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  15 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  16 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  17 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  18 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  19 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  20 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  21 and  if  terminal is  : False
# ...
#  the len of the df is  248  and the current day is :  70 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  71 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  72 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  73 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  74 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  75 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  76 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  77 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  78 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  79 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  80 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  81 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  82 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  83 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  84 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  85 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  86 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  87 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  88 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  89 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  90 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  91 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  92 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  93 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  94 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  95 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  96 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  97 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  98 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  99 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  100 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  101 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  102 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  103 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  104 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  105 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  106 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  107 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  108 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  109 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  110 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  111 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  112 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  113 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  114 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  115 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  116 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  117 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  118 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  119 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  120 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  121 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  122 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  123 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  124 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  125 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  126 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  127 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  128 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  129 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  130 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  131 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  132 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  133 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  134 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  135 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  136 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  137 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  138 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  139 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  140 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  141 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  142 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  143 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  144 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  145 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  146 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  147 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  148 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  149 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  150 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  151 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  152 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  153 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  154 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  155 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  156 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  157 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  158 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  159 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  160 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  161 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  162 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  163 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  164 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  165 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  166 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  167 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  168 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  169 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  170 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  171 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  172 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  173 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  174 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  175 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  176 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  177 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  178 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  179 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  180 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  181 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  182 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  183 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  184 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  185 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  186 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  187 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  188 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  189 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  190 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  191 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  192 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  193 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  194 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  195 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  196 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  197 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  198 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  199 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  200 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  201 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  202 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  203 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  204 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  205 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  206 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  207 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  208 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  209 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  210 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  211 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  212 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  213 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  214 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  215 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  216 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  217 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  218 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  219 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  220 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  221 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  222 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  223 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  224 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  225 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  226 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  227 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  228 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  229 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  230 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  231 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  232 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  233 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  234 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  235 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  236 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  237 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  238 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  239 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  240 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  241 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  242 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  243 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  244 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  245 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  246 and  if  terminal is  : False
#  the len of the df is  248  and the current day is :  247 and  if  terminal is  : True
# =================================
# begin_total_asset:1000000
# end_total_asset:1018180.0177390797
# Sharpe:
# 0.1921113658285049
# =================================
# hit end!
#  the reward is :::::::    [9356.186]
# 100%|██████████| 10/10 [01:16<00:00,  7.64s/trial, best loss: -0.7649051580979576]

# %%
best['Aact_fn'] = ['relu', 'tanh', 'sigmoid'][best['Aact_fn']]
best['Cact_fn'] = ['relu', 'tanh', 'sigmoid'][best['Cact_fn']]
best
# Out:
# {'Aact_fn': 'relu',
#  'Adr': np.float64(0.04797852419088189),
#  'Ahidden_dim': np.float64(312.0),
#  'Anum_layers': np.float64(7.0),
#  'Cact_fn': 'relu',
#  'Cdr': np.float64(0.2879033047322268),
#  'Chidden_dim': np.float64(320.0),
#  'Cnum_layers': np.float64(2.0),
#  'alr': np.float64(0.0049696088046112),
#  'batch_size': np.float64(192.0),
#  'buffer_size': np.float64(440000.0),
#  'clr': np.float64(0.0044060842707457975),
#  'gamma': np.float64(0.9096465857670457),
#  'grad_clip': np.float64(3.057655984293454),
#  'noise_std': np.float64(0.014998599706119858),
#  'reward_scaling': np.float64(7.9575999606829555),
#  'rho': np.float64(0.04802974301785835),
#  'tau': np.float64(0.14264676908863416),
#  'warmup_steps': np.float64(18000.0)}

# %%
# best= {'Aact_fn': 'sigmoid',
#  'Adr': np.float64(0.40156739994186963),
#  'Ahidden_dim': np.float64(320.0),
#  'Anum_layers': np.float64(2.0),
#  'Cact_fn': 'tanh',
#  'Cdr': np.float64(0.1254413062439358),
#  'Chidden_dim': np.float64(251.0),
#  'Cnum_layers': np.float64(5.0),
#  'alr': np.float64(0.0009107119585481395),
#  'batch_size': np.float64(128.0),
#  'buffer_size': np.float64(750000.0),
#  'clr': np.float64(0.011909541457606108),
#  'gamma': np.float64(0.9802858202890133),
#  'grad_clip': np.float64(4.985696483611227),
#  'lambda_init': np.float64(0.4925723364653761),
#  'noise_std': np.float64(0.23649933117828195),
#  'reward_scaling': np.float64(4.922508316091725),
#  'rho': np.float64(0.0701825073670665),
#  'tau': np.float64(0.1185136176470432),
#  'warmup_steps': np.float64(9000.0)}

# %%
agent = DDPGagent(env_full_train, best)

batch_size = agent.batch_size
# Out:
#  DDPG AGEnt Class- ++++++++++++++++++++++++++++++++++++++++++

# %%
rewards = []
avg_rewards = []
num_episodes = 5 #1000

torch.autograd.set_detect_anomaly(True)
for episode in range(num_episodes):

    state = env_full_train.reset()
    episode_reward = 0
    done = False
    # print(state.shape, type(state))
    # state = state.reshape(1, 1, 39, 30)
    # print((torch.tensor( np.expand_dims(state, axis=1))).dim)



    print(f"Episode: {episode+1}")
    while not done:

        # print(i)
        # print(f"done  : {done} ")
        action = agent.get_action(state)
        action = Noise(action, env_full_train.action_space)
        new_state, reward, done ,info = env_full_train.step(action)
        # done= terminated or truncated
        agent.memory.push(state, action, reward, new_state, done)

        if len(agent.memory) > batch_size:
            agent.update()

        state = new_state
        episode_reward  = episode_reward + reward

        if done:
          #  sys.stdout.write("episode: {}, reward: {}, average _reward: {} \n".format(episode, np.round(episode_reward, decimals=2), np.mean(rewards[-10:])))
            break

    # agent.lambda_ = agent.lambda_ + agent.rho * agent.cost_network.forward(torch.tensor( np.expand_dims(state, axis=1)), agent.get_action(state)).mean()
    # agent.lambda_ = agent.lambda_ + agent.rho * agent.cost_network.forward(
                  #     torch.tensor(np.expand_dims(state, axis=1), dtype=torch.float32),
                  #     agent.get_action(state)
                  # ).mean().detach()

    device = next(agent.cost_network.parameters()).device  # Get the device of the cost network

    state_tensor = torch.tensor(np.expand_dims(state, axis=1), dtype=torch.float32, device=device)
    action_tensor = agent.get_action(state).to(device)  # Ensure action is also on same device

    agent.lambda_ = agent.lambda_ + agent.rho * agent.cost_network.forward(
        state_tensor,
        action_tensor
    ).mean().detach().to(device)

    agent.rho= agent.rho * 1.008

    rewards.append(episode_reward)
    avg_rewards.append(np.mean(rewards[-10:]))
    print(f"Episode: {episode+1}, Total Reward: {episode_reward}")
    print(" violations : " ,  agent.violations)
# Out:
# Episode: 1
#  the len of the df is  2707  and the current day is :  0 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  2 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  3 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  4 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  5 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  6 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  7 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  8 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  9 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  10 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  11 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  12 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  13 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  14 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  15 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  16 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  17 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  18 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  19 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  20 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  21 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  22 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  23 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  24 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  25 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  26 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  27 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  28 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  29 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  30 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  31 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  32 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  33 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  34 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  35 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  36 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  37 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  38 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  39 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  40 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  41 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  42 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  43 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  44 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  45 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  46 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  47 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  48 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  49 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  50 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  51 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  52 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  53 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  54 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  55 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  56 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  57 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  58 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  59 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  60 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  61 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  62 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  63 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  64 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  65 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  66 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  67 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  68 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  69 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  70 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  71 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  72 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  73 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  74 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  75 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  76 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  77 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  78 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  79 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  80 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  81 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  82 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  83 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  84 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  85 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  86 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  87 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  88 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  89 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  90 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  91 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  92 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  93 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  94 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  95 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  96 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  97 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  98 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  99 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  100 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  101 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  102 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  103 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  104 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  105 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  106 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  107 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  108 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  109 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  110 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  111 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  112 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  113 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  114 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  115 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  116 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  117 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  118 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  119 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  120 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  121 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  122 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  123 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  124 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  125 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  126 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  127 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  128 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  129 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  130 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  131 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  132 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  133 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  134 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  135 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  136 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  137 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  138 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  139 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  140 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  141 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  142 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  143 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  144 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  145 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  146 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  147 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  148 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  149 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  150 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  151 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  152 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  153 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  154 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  155 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  156 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  157 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  158 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  159 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  160 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  161 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  162 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  163 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  164 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  165 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  166 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  167 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  168 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  169 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  170 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  171 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  172 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  173 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  174 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  175 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  176 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  177 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  178 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  179 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  180 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  181 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  182 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  183 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  184 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  185 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  186 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  187 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  188 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  189 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  190 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  191 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  192 and  if  terminal is  : False
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/loss.py:610: UserWarning: Using a target size (torch.Size([192, 192, 1])) that is different to the input size (torch.Size([192, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/loss.py:610: UserWarning: Using a target size (torch.Size([192, 192])) that is different to the input size (torch.Size([192, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
#  the len of the df is  2707  and the current day is :  193 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  194 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  195 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  196 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  197 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  198 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  199 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  200 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  201 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  202 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  203 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  204 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  205 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  206 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  207 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  208 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  209 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  210 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  211 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  212 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  213 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  214 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  215 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  216 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  217 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  218 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  219 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  220 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  221 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  222 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  223 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  224 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  225 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  226 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  227 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  228 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  229 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  230 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  231 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  232 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  233 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  234 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  235 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  236 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  237 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  238 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  239 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  240 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  241 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  242 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  243 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  244 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  245 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  246 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  247 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  248 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  249 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  250 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  251 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  252 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  253 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  254 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  255 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  256 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  257 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  258 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  259 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  260 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  261 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  262 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  263 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  264 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  265 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  266 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  267 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  268 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  269 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  270 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  271 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  272 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  273 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  274 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  275 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  276 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  277 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  278 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  279 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  280 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  281 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  282 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  283 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  284 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  285 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  286 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  287 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  288 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  289 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  290 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  291 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  292 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  293 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  294 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  295 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  296 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  297 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  298 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  299 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  300 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  301 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  302 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  303 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  304 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  305 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  306 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  307 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  308 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  309 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  310 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  311 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  312 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  313 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  314 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  315 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  316 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  317 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  318 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  319 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  320 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  321 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  322 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  323 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  324 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  325 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  326 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  327 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  328 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  329 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  330 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  331 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  332 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  333 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  334 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  335 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  336 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  337 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  338 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  339 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  340 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  341 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  342 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  343 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  344 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  345 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  346 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  347 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  348 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  349 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  350 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  351 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  352 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  353 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  354 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  355 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  356 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  357 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  358 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  359 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  360 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  361 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  362 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  363 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  364 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  365 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  366 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  367 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  368 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  369 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  370 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  371 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  372 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  373 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  374 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  375 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  376 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  377 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  378 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  379 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  380 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  381 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  382 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  383 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  384 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  385 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  386 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  387 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  388 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  389 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  390 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  391 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  392 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  393 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  394 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  395 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  396 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  397 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  398 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  399 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  400 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  401 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  402 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  403 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  404 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  405 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  406 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  407 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  408 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  409 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  410 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  411 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  412 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  413 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  414 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  415 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  416 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  417 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  418 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  419 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  420 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  421 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  422 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  423 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  424 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  425 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  426 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  427 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  428 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  429 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  430 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  431 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  432 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  433 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  434 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  435 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  436 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  437 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  438 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  439 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  440 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  441 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  442 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  443 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  444 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  445 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  446 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  447 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  448 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  449 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  450 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  451 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  452 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  453 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  454 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  455 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  456 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  457 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  458 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  459 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  460 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  461 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  462 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  463 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  464 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  465 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  466 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  467 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  468 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  469 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  470 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  471 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  472 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  473 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  474 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  475 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  476 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  477 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  478 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  479 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  480 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  481 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  482 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  483 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  484 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  485 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  486 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  487 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  488 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  489 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  490 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  491 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  492 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  493 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  494 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  495 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  496 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  497 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  498 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  499 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  500 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  501 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  502 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  503 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  504 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  505 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  506 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  507 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  508 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  509 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  510 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  511 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  512 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  513 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  514 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  515 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  516 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  517 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  518 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  519 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  520 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  521 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  522 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  523 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  524 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  525 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  526 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  527 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  528 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  529 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  530 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  531 and  if  terminal is  : False
# ...
#  the len of the df is  2707  and the current day is :  1405 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1406 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1407 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1408 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1409 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1410 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1411 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1412 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1413 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1414 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1415 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1416 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1417 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1418 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1419 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1420 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1421 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1422 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1423 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1424 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1425 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1426 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1427 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1428 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1429 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1430 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1431 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1432 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1433 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1434 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1435 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1436 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1437 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1438 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1439 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1440 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1441 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1442 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1443 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1444 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1445 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1446 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1447 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1448 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1449 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1450 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1451 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1452 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1453 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1454 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1455 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1456 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1457 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1458 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1459 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1460 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1461 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1462 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1463 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1464 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1465 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1466 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1467 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1468 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1469 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1470 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1471 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1472 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1473 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1474 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1475 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1476 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1477 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1478 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1479 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1480 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1481 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1482 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1483 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1484 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1485 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1486 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1487 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1488 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1489 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1490 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1491 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1492 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1493 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1494 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1495 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1496 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1497 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1498 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1499 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1500 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1501 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1502 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1503 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1504 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1505 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1506 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1507 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1508 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1509 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1510 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1511 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1512 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1513 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1514 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1515 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1516 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1517 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1518 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1519 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1520 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1521 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1522 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1523 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1524 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1525 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1526 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1527 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1528 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1529 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1530 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1531 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1532 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1533 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1534 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1535 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1536 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1537 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1538 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1539 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1540 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1541 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1542 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1543 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1544 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1545 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1546 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1547 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1548 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1549 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1550 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1551 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1552 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1553 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1554 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1555 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1556 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1557 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1558 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1559 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1560 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1561 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1562 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1563 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1564 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1565 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1566 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1567 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1568 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1569 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1570 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1571 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1572 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1573 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1574 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1575 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1576 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1577 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1578 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1579 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1580 and  if  terminal is  : False
#  the len of the df is  2707  and the current day is :  1581 and  if  terminal is  : False

# %%
import pickle
import matplotlib.pyplot as plt
from google.colab import files
# Save to file
with open("ddpg_agent.pkl", "wb") as f:
    pickle.dump(agent, f)

files.download("ddpg_agent.pkl")

# %%
# Create a figure and axis
fig, ax = plt.subplots()

# Plot the rewards
ax.plot(rewards, label='Rewards')
ax.plot(avg_rewards, label='Average Rewards')

# Label the axes
ax.set_xlabel('Episode')
ax.set_ylabel('Reward')

# Add legend
ax.legend()

# Show the plot
plt.show()
fig.savefig('rewards_plot.png')
files.download("rewards_plot.png")

# Now `fig` contains the plot and can be saved or manipulated

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at 2019-01-01. We use the A2C model to trade Dow jones 30 stocks.

# %% [markdown]
# import the trading dataframe  and hist_vol dataframe

# %%
# indices= [sensex_ticker, Dow_30, dax_30, nikkei_top30_symbols, FTSE_top30, twse_top30, hang_seng_symbols, brazil_tickers, ibex35_tickers, bist100_top30_tickers ]

# # indices = {
# #     "sensex_ticker": sensex_ticker,
# #     "Dow_30": Dow_30,
# #     "dax_30": dax_30,
# #     "nikkei_top30_symbols": nikkei_top30_symbols,
# #     "FTSE_top30": FTSE_top30,
# #     "twse_top30": twse_top30,
# #     "hang_seng_symbols": hang_seng_symbols,
# #     "brazil_tickers": brazil_tickers,
# #     "ibex_35_tickers": ibex35_tickers,
# #     "bist100_top30_tickers": bist100_top30_tickers
# # }

# file_name= "____index that u  want to  trade into __ "

# df= pd.read_csv(f'/content/stock_data_{file_name}')
# hist_vol_trade = pd.read_csv(f'/content/hist_vol_{file_name}')

# %%
trade = data_split(df,'2023-01-01', '2025-02-28')

# %%
TURBULENCE_THRESHOLD
env_kwargs_trade = {
    "hmax": 100,
    "initial_amount": 1000000,
    "transaction_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4,
    "hist_vol":hist_vol_trade,
    "turbulence_threshold": TURBULENCE_THRESHOLD
}

# %%
e_trade_gym = StockPortfolioEnv(df = trade, **env_kwargs_trade)
test_env, test_obs = e_trade_gym.get_sb_env()

# %%
account_memory, actions_memory, rewardd = agent.trade(env_trade, e_trade_gym)
violations= agent.violations

print("violations : " , violations)
print(" reward :: " , rewardd)

# %%
calculate_sharpe(account_memory[0])

# %%
account_memory[0].head()

# %%
account_memory[0].to_csv('/content/df_daily_return.csv')
files.download('df_daily_return.csv')

# %%
actions_memory[0].head()

# %%
actions_memory[0].to_csv('/content/df_actions.csv')
files.download('df_actions.csv')

# %%
df_daily_return = account_memory[0]

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
#calculate_portfolio_minimum_variance
portfolio = pd.DataFrame(index = range(1), columns = unique_trade_date)
initial_capital = 1000000
portfolio.loc[0,unique_trade_date[0]] = initial_capital

# Define transaction cost rate
transaction_cost_rate = 0.005

for i in range(len( unique_trade_date)-1):
    df_temp = df[df.date==unique_trade_date[i]].reset_index(drop=True)
    df_temp_next = df[df.date==unique_trade_date[i+1]].reset_index(drop=True)
    #Sigma = risk_models.sample_cov(df_temp.return_list[0])
    #calculate covariance matrix
    Sigma = df_temp.return_list[0].cov()
    #portfolio allocation
    ef_min_var = EfficientFrontier(None, Sigma,weight_bounds=(0, 0.1))
    #minimum variance
    raw_weights_min_var = ef_min_var.min_volatility()
    #get weights
    cleaned_weights_min_var = ef_min_var.clean_weights()

    #current capital
    cap = portfolio.iloc[0, i]
    #current cash invested for each stock
    current_cash = [element * cap for element in list(cleaned_weights_min_var.values())]
    # current held shares
    current_shares = list(np.array(current_cash)
                                      / np.array(df_temp.close))
    # next time period price
    next_price = np.array(df_temp_next.close)

    # Calculate next portfolio value without transaction cost
    next_value = np.dot(current_shares, next_price)

    # Calculate transaction costs
    new_shares = current_cash / next_price
    share_differences = np.abs(new_shares - current_shares)
    transaction_cost = np.sum(share_differences * next_price * transaction_cost_rate)

    # Deduct transaction cost from portfolio value
    portfolio.iloc[0, i + 1] = next_value - transaction_cost

portfolio=portfolio.T
portfolio.columns = ['account_value']

# %%
def calculate_daily_return(current_value, previous_value):
    return (current_value - previous_value) / previous_value

# Calculate daily return and add it as a new column
daily_returns = [0]  # Daily return for the first day is assumed to be 0
for i in range(1, len(portfolio)):
    current_value = portfolio['account_value'][i]
    previous_value = portfolio['account_value'][i - 1]
    daily_returns.append(calculate_daily_return(current_value, previous_value))

portfolio['daily_return'] = daily_returns

print(portfolio)

# %%
portfolio.head()

# %%
Agent =(df_daily_return_T.daily_return+1).cumprod()-1

# %%
min_var_cumpod =(portfolio.account_value.pct_change()+1).cumprod()-1

# %%
portfolio.drop(columns=['account_value'], inplace=True)
portfolio.to_csv('Markowitz_Portfolio_Return_'+ Market +'.csv')
files.download('Markowitz_Portfolio_Return_'+ Market +'.csv')

# %%
Baseline =(baseline_returns+1).cumprod()-1

# %% [markdown]
# ## Plotly: DRL, Min-Variance, DJIA

# %%
# %pip install plotly

# %%
from datetime import datetime as dt

import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go

# %%
time_ind = pd.Series(df_daily_return_T.date)

# %%
trace0_portfolio = go.Scatter(x = time_ind, y = Agent, mode = 'lines', name = 'Agent (Portfolio Allocation)')

trace1_portfolio = go.Scatter(x = time_ind, y = Baseline, mode = 'lines', name = 'Baseline')
trace2_portfolio = go.Scatter(x = time_ind, y = min_var_cumpod, mode = 'lines', name = 'Min-Variance')
#trace3_portfolio = go.Scatter(x = time_ind, y = a2c_cumpod_esg, mode = 'lines', name = 'ESG-A2C (Portfolio Allocation)')
#trace3_portfolio = go.Scatter(x = time_ind, y = ddpg_cumpod, mode = 'lines', name = 'DDPG')
#trace4_portfolio = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')
#trace5_portfolio = go.Scatter(x = time_ind, y = min_cumpod, mode = 'lines', name = 'Min-Variance')

#trace4 = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')

#trace2 = go.Scatter(x = time_ind, y = portfolio_cost_minv, mode = 'lines', name = 'Min-Variance')
#trace3 = go.Scatter(x = time_ind, y = spx_value, mode = 'lines', name = 'SPX')

# %%
fig = go.Figure()
fig.add_trace(trace0_portfolio)

fig.add_trace(trace1_portfolio)

fig.add_trace(trace2_portfolio)

#fig.add_trace(trace3_portfolio)

fig.update_layout(
    legend=dict(
        x=0,
        y=1,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=15,
            color="black"
        ),
        bgcolor="White",
        bordercolor="white",
        borderwidth=2

    ),
)
#fig.update_layout(legend_orientation="h")
fig.update_layout(title={
        #'text': "Cumulative Return using FinRL",
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
#with Transaction cost
#fig.update_layout(title =  'Quarterly Trade Date')
fig.update_layout(
#    margin=dict(l=20, r=20, t=20, b=20),

    paper_bgcolor='rgba(1,1,0,0)',
    plot_bgcolor='rgba(1, 1, 0, 0)',
    #xaxis_title="Date",
    yaxis_title="Cumulative Return",
xaxis={'type': 'date',
       'tick0': time_ind[0],
        'tickmode': 'linear',
       'dtick': 86400000.0 *80}

)
fig.update_xaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')

fig.show()
